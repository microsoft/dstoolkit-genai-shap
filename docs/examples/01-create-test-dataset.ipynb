# %% [markdown]
# <h1 align="center">
#     <img
#         src="../img/logo_white_bg.jpeg"
#         width="200"
#         border="1" />
# </h1>
# <h1 align="center">
#     <b>GenAISHAP</b>
# </h1>
# <h4 align="center">
#     <i>Explanations for Generative AI, LLM-and-SLM-Based, Solutions</i> ⚡️
# </h4>
#
#
#
# Generative AI SHAP (GenAISHAP) is a python library that supports the creation of explanations to the metrics obtained for solutions based on LLMs (Large Language Models) or SLMs (Small Language Models).
#
# When building an LLM-or-SLM based solution one of the first challenges is how to measure the quality of the responses from the "Agent". Here, libraries like  [RAGAS](https://github.com/explodinggradients/ragas) or [promptflow](https://github.com/microsoft/promptflow) help on the evaluation of the quality of the solution by using metrics like **faithfulness**, **groundedness**, **context precision**, **context recall**, among others.
#
# The open challenge is to add explainability to those quality metrics.  To answer questions like:
#
# - *Why a particular question is marked with a higher/lower metric (e.g., faithfulness)?*
# - *What are the common characteristics of the user questions that produce good or bad **faithfulness**?*
# - *What type of prompts produce better or lower **context recall**?*
#
# The answer of those questions helps on the debugging of the overall solution and gives more insights to where to focus the next steps to improve the metrics.
#
# This notebook shows an example of how to create the **Input** for GenAISHAP, which is a simple Pandas DataFrame with the evaluation dataset. This dataset should have at least the following columns:
#
# - User input, question or prompt. Column name should be `user_input` and its type should be string.
# - One column for each metric already calculated, for example **faithfulness**, **context precision**, **context recall**.  All numerical columns will be assumed to be a metric column.
#
# At the end of this notebook a pandas Dataframe like the following will be produced:
#
# <img src="../img/input_example.png" width="1200" />
#
# > In this example, the column `user_input` will be used to refer to the user prompt, and the columns `faithfulness`, `context_precision` and `context_recall` will be used as metric columns since those columns are numerical.
# >
# > The other columns, `retrieved_contexts`, `response`, and `reference` are not needed for **GenAISHAP** but are normally required for the calculation of the metrics.
#
# # 1. Import relevant libraries and load environment variables
#
# Make sure that before you run this notebook you have a `.env` file with the following variables with their respective values:
#
# - OPENAI_API_VERSION
# - AZURE_OPENAI_ENDPOINT
# - OPENAI_API_KEY
# - PYTHONIOENCODING=utf-8
# - PYTHONUTF8=1
#
# > Note that here we are not importing **genaishap** library, since this notebooks is only an example of how to create the input for the GenAISHAP execution.

# %%
from llama_index.core.llama_dataset import LabelledRagDataset
from llama_index.core.readers import SimpleDirectoryReader
from dotenv import load_dotenv
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
import os
from llama_index.core import VectorStoreIndex, Settings
from ragas.metrics import (
    Faithfulness,
    ContextPrecision,
    ContextRecall
)
from ragas.llms import LlamaIndexLLMWrapper
from ragas.embeddings import LlamaIndexEmbeddingsWrapper
from ragas.dataset_schema import SingleTurnSample, EvaluationDataset
from ragas.evaluation import evaluate
from ragas.run_config import RunConfig

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. Load the example dataset
#
# As an example the [Mini Esg Bench Dataset](https://llamahub.ai/l/llama_datasets/Mini%20ESG%20Bench%20Dataset?from=llama_datasets) dataset will be used.  This dataset provides, among others:
#
# - 6 PDFs with the 2022 or 2021 sustainability report from Microsoft, Apple, Amazon, Google, Meta and Netflix.
# - 50 user queries that should be answered using those documents.
# - Reference answer for each query that will be used as ground truth to calculate the RAGAS metrics.

# %%
rag_dataset = LabelledRagDataset.from_json("./data/rag_dataset.json")
documents = SimpleDirectoryReader(input_dir="./data/source_files/").load_data(
    show_progress=True
)
# Out:
# Loading files: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:19<00:00,  3.25s/file]

# %% [markdown]
# It should have created a folder named `data` with 2 elements:
# - a `rag_dataset.json` file with the information shown after executing the next cell.
# - a `source_files` folder with a single TXT file with the full Paul Graham Essay.

# %%
rag_dataset.to_pandas()
# Out:
#                                                 query  \
# 0   What is the objective of the Carbon Call initi...
# 1   What are the three key areas that will enable ...
# 2   How many people in India did Microsoft provide...
# 3   How many people in Indonesia did Microsoft pro...
# 4   How many people in Brazil did Microsoft provid...
# 5   How many people in Mexico did Microsoft provid...
# 6   How many more acres of land does Microsoft nee...
# 7   What key insight was listed in page 56 of the ...
# 8   What key insight was listed in page 61 of the ...
# 9    What are the four commitments listed on page 66?
# 10  What is the last Key project listed under Poli...
# 11  What are the sub sections for "What We Create"...
# 12  What are the category labels for each topic in...
# 13  Can you provide for me the three highlights fo...
# 14  What percentage of waste from Google's offices...
# 15  Can you present me with the performance highli...
# 16  What was the listed key achievement regarding ...
# 17  Did Google reach its intended Waste target und...
# 18  How many EV charging locations were there on G...
# 19  On what page of the report can I find the perf...
# 20  Can you please provide for me the glossary of ...
# 21  On what page can I find details about Amazons ...
# 22  For the listed Renewable Energy goals, by when...
# 23  Can you provide the Actions taken by Amazon fo...
# 24  What were Amazon's Carbon Intesity values in (...
# 25  What were Amazon's Total Carbon Footprint (MMT...
# 26  On what page can of the report can I find info...
# 27  What household brands were featured in the in ...
# 28  What percentage of corporate emissions since 2...
# 29  In Apple's comprehensive carbon footprint, wha...
# 30  By what percentage did Apple reduce plastic in...
# 31  How many metric tons of waste were redirected ...
# 32  In 2021, how many hours were spent by staff ac...
# 33  How many millions of gallons of freshwater was...
# 34  What were the Total Packaging resources used i...
# 35  How many pages and groups were removed for rep...
# 36  How many artifacts were removed from Facebook ...
# 37  How many unique visitors to the Facebook Marke...
# 38  How many users were surveyed for their views o...
# 39  What were the subsections for the 2021 Highlig...
# 40  What are the subsections of the Workplaces sec...
# 41   What is the fact about Oceans shared on page 43?
# 42  What are the 4 facts shared in the Greenhouse ...
# 43  In the about netflix page, what are the mentio...
# 44  Who provided the testimonial on Netflix's Sust...
# 45  What are the Scope 1 and Scope 2 emission redu...
# 46  Who provided the testimonial on Netflix's Sust...
# 47         Can you provide the quote by Xiye Bastida?
# 48         Can you provide the quote by Aditi Sharma?
# 49  What 3 partner companies were spotlighted in t...
#
#                                    reference_contexts  \
# 0   [In February 2022, Microsoft, ClimateWorks Fou...
# 1   [We will continue\ninvesting in three key area...
# 2   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 3   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 4   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 5   [Water Table 3\n\nIndia: 309,921\nIndonesia: 2...
# 6   [Ecosystems Chart 1\nAchieving our target of p...
# 7   [25%\nWe are reducing idle\npower consumption\...
# 8   [100%\nOur key European\nand American\ndistrib...
# 9   [Our commitment\nUsing our voice on climate-re...
# 10  [Making green jobs, skills, and\nentrepreneurs...
# 11  [64 What We Create\nRaising Awareness\nTacklin...
# 12              [Important, Very Important, Critical]
# 13  [GHG emissions\n65%\ncumulative GHG\nemissions...
# 14  [64%\nlandfill diversion\nIn 2021, we reached ...
# 15  [EMPOWERING USERS WITH TECHNOLOGY\nProducts\nT...
# 16  [We’ve been a leader on sustainability and cli...
# 17  [Target: Achieve UL 2799 Zero Waste to Landfil...
# 18  [200,000\nEV charging locations\non Google Map...
# 19  [EMPOWERING USERS WITH TECHNOLOGY\nProducts\nT...
# 20  [Glossary\nCFE: carbon-free energyCO2e: carbon...
# 21  [Contents\nIntroduction\n2 About Amazon\n3 Ope...
# 22  [Renewable Energy\nGoal: Power our operations ...
# 23  [Actions\n90% Electricity consumed by Amazon a...
# 24  [Amazon’s Enterprisewide Carbon Footprint, 201...
# 25  [Emissions Category (MMT CO2e) 2019 2020 2021 ...
# 26  [IntroductionSustainabilityDriving Climate Sol...
# 27  [The Climate Pledge\nThe Climate Pledge is a c...
# 28  [Carbon neutral for\ncorporate emissions\nSinc...
# 29  [Supplier clean energy:\n13.9 million metric t...
# 30  [75%\nWe’ve reduced the plastic in our packagi...
# 31  [2M+\nmetric tons of waste redirected from\nla...
# 32  [In fiscal year 2021,\nteam members spent more...
# 33  [Supply chain Freshwater saved million gallons...
# 34  [Product packaging footprint\nTotal packaging ...
# 35  [3000\nPages and groups\nremoved for\nrepeated...
# 36  [12Million\nPieces of\nmisleading\nCOVID-19\ni...
# 37  [368,000\nUnique Visitors\nto the Facebook\nMa...
# 38  [76,328\nFacebook users\nreached with the\nCli...
# 39  [2021 Highlights\nThrough operational improvem...
# 40  [Workplaces\nHealthy and Sustainable\nWorkplac...
# 41  [Oceans absorb\nmore than 90% of\nthe heat tha...
# 42  [1. CO2 emissions are increasing more than 250...
# 43  [Public in 2002\nFounded in 1997\n231M paid me...
# 44  [Netflix’s Sustainability Strategy is music to...
# 45  [Action\nEnergy Efficiency\nRenewable Energy (...
# 46  [This is what industry leadership looks like. ...
# 47  [Young people like myself view Netflix as a ch...
# 48  [Aditi Sharma\nGraduate of the Netflix x Film ...
# 49  [Netflix ESG Report 2022 48\nWith a catalytic ...
#
#                                      reference_answer reference_answer_by  \
# 0   The objective of Carbon Call is to unify the w...               human
# 1   1 Advancing AI solutions for greater climate i...               human
# 2                                             309,921               human
# 3                                             225,389               human
# 4                                              16,408               human
# 5                                                 340               human
# 6                                     4998 more acres               human
# 7   25%\nWe are reducing idle power consumption of...               human
# 8   100%\nOur key European and American distributi...               human
# 9   1. Using our voice on climate-related public p...               human
# 10  Making green jobs, skills, and entrepreneurshi...               human
# 11  Raising Awareness, Tackling Climate Misinforma...               human
# 12                Important, Very Important, Critical               human
# 13  Sure, they are: \n1. 65% cumulative GHG emissi...               human
# 14                                Sixty-four percent.               human
# 15  Sure! The Performance Highlights for Empowerin...               human
# 16  In 2017, Google became the first major company...               human
# 17  No, this target has not been met in 2021. Howe...               human
# 18                                             200000               human
# 19  The performance highlights for Empowering User...               human
# 20  Sure, here is the glossary:\nGlossary\nCFE: ca...               human
# 21  You can find information on driving climate so...               human
# 22  Amazon set the goal of becoming powered by 100...               human
# 23  Sure, here they are:\nActions\n90% Electricity...               human
# 24  Sure, here they are:\n2019: 122.8\n2020: 102.7...               human
# 25  Amazon's total footprint for the years 2019-20...               human
# 26                                         On page 14               human
# 27  Microsoft, jetBlue, Uber, Mercedez-Benz, Visa,...               human
# 28                             100% since April 2020.               human
# 29  The top two categories were: supplier clean en...               human
# 30                                                75%               human
# 31  More than 2 million metric tons of waste were ...               human
# 32                                       175000 hours               human
# 33  7600 million gallons of freshwater were saved ...               human
# 34  2021: 257000\n2020: 226000\n2019: 189000\n2018...               human
# 35                                               3000               human
# 36                                           12000000               human
# 37                                             368000               human
# 38                   76328 users across 31 countries.               human
# 39  1 Protecting People and Planet Through Respons...               human
# 40  1. Healthy and Sustainable Workplaces\n2. Offi...               human
# 41  Oceans absorb more than 90% ofthe heat that re...               human
# 42  1. CO2 emissions are increasing more than 250 ...               human
# 43  Public in 2002\nFounded in 1997\n231M paid mem...               human
# 44  Christiana Figueres,\nDiplomat and Architect o...               human
# 45  1 Energy Efficiency\n2 Renewable Energy (elect...               human
# 46  Elizabeth Sturcken,\nManaging Director, Enviro...               human
# 47  Young people like myself view Netflix as a che...               human
# 48  Through the Take Ten program, I got to learn a...               human
# 49  1. Black Economic Development Fund\n2. Hope Cr...               human
#
#    query_by
# 0     human
# 1     human
# 2     human
# 3     human
# 4     human
# 5     human
# 6     human
# 7     human
# 8     human
# 9     human
# 10    human
# 11    human
# 12    human
# 13    human
# 14    human
# 15    human
# 16    human
# 17    human
# 18    human
# 19    human
# 20    human
# 21    human
# 22    human
# 23    human
# 24    human
# 25    human
# 26    human
# 27    human
# 28    human
# 29    human
# 30    human
# 31    human
# 32    human
# 33    human
# 34    human
# 35    human
# 36    human
# 37    human
# 38    human
# 39    human
# 40    human
# 41    human
# 42    human
# 43    human
# 44    human
# 45    human
# 46    human
# 47    human
# 48    human
# 49    human

# %% [markdown]
# # 3. Create semantic index for RAG
#
# The following cell creates the connection object to the embedding and language model that will be used to calculate the response from each user query in the dataset:

# %%
embed_model = AzureOpenAIEmbedding(
    model='text-embedding-3-small', # Update with the embeddings deployment name
    api_key=os.environ['OPENAI_API_KEY'],
    api_version=os.environ['OPENAI_API_VERSION'],
    azure_endpoint=os.environ['AZURE_OPENAI_ENDPOINT']
)

llm = AzureOpenAI(
    engine="gpt-4o", # Update with the language model deployment name 
    model="gpt-4o", # Update with the language model name
    temperature=0.0,
    api_key=os.environ['OPENAI_API_KEY'],
    api_version=os.environ['OPENAI_API_VERSION'],
    azure_endpoint=os.environ['AZURE_OPENAI_ENDPOINT']
)

# %% [markdown]
# The next two cells create the "in-memory" semantic index with chunks of the essay

# %%
Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(
    documents=documents,
    show_progress=True
)
query_engine = index.as_query_engine()
# Out:
# Parsing nodes:   0%|          | 0/455 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/508 [00:00<?, ?it/s]

# %% [markdown]
# # 4. Calculate the reponse
# The next cell calculates the response by querying the semantic index and calling the language model. After this step the following elements are calculated for each user query in the original dataset:
#
# - `retrieved_context`. Which contains the list of the top chuncks retrieved from the semantic index as context for the LLM to calculate the answer.
# - `response`. Response of the LLM to the user query using the retrieved chunks as context.
#
# > *This process could take several minutes, even hours, depending on the rate limit (max tokens per minute) of the deployments used.*

# %%
# %%time
predictions = rag_dataset.make_predictions_with(
    predictor = query_engine,
    show_progress = True,
    batch_size = 20
)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:33<00:00,  1.67s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:24<00:00,  1.24s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:12<00:00,  1.22s/it]
# CPU times: user 2.81 s, sys: 84.7 ms, total: 2.89 s
# Wall time: 1min 10s

# %% [markdown]
# # 5. Data preparation for the calculation of the RAGAS metrics
#
# The following cell shows an example of how to prepare the data for the calculation of the RAGAS metrics. For this example we only need to use the following elements:
#
# - `user_input`. In this case, the user input is just the `query` in the original dataset.
# - `reference`.  Reference column in ragas is the **expected answer**. We have it as `reference_answer` in the original dataset.
# - `response`. Bot response. We just calculated it in the last step.
# - `retrieved_contexts`. List of documents or chunks used as context for the Bot to create the answer. It was also calculated in the last step.

# %%
list_of_samples = []

for idx in range(len(rag_dataset.examples)):
    list_of_samples.append(
        SingleTurnSample (
            user_input = rag_dataset.examples[idx].query,
            reference = rag_dataset.examples[idx].reference_answer,
            response = predictions.predictions[idx].response,
            retrieved_contexts = predictions.predictions[idx].contexts
        )
    )

ragas_evaluation_dataset = EvaluationDataset(list_of_samples)
ragas_evaluation_dataset.to_pandas()
# Out:
#                                            user_input  \
# 0   What is the objective of the Carbon Call initi...
# 1   What are the three key areas that will enable ...
# 2   How many people in India did Microsoft provide...
# 3   How many people in Indonesia did Microsoft pro...
# 4   How many people in Brazil did Microsoft provid...
# 5   How many people in Mexico did Microsoft provid...
# 6   How many more acres of land does Microsoft nee...
# 7   What key insight was listed in page 56 of the ...
# 8   What key insight was listed in page 61 of the ...
# 9    What are the four commitments listed on page 66?
# 10  What is the last Key project listed under Poli...
# 11  What are the sub sections for "What We Create"...
# 12  What are the category labels for each topic in...
# 13  Can you provide for me the three highlights fo...
# 14  What percentage of waste from Google's offices...
# 15  Can you present me with the performance highli...
# 16  What was the listed key achievement regarding ...
# 17  Did Google reach its intended Waste target und...
# 18  How many EV charging locations were there on G...
# 19  On what page of the report can I find the perf...
# 20  Can you please provide for me the glossary of ...
# 21  On what page can I find details about Amazons ...
# 22  For the listed Renewable Energy goals, by when...
# 23  Can you provide the Actions taken by Amazon fo...
# 24  What were Amazon's Carbon Intesity values in (...
# 25  What were Amazon's Total Carbon Footprint (MMT...
# 26  On what page can of the report can I find info...
# 27  What household brands were featured in the in ...
# 28  What percentage of corporate emissions since 2...
# 29  In Apple's comprehensive carbon footprint, wha...
# 30  By what percentage did Apple reduce plastic in...
# 31  How many metric tons of waste were redirected ...
# 32  In 2021, how many hours were spent by staff ac...
# 33  How many millions of gallons of freshwater was...
# 34  What were the Total Packaging resources used i...
# 35  How many pages and groups were removed for rep...
# 36  How many artifacts were removed from Facebook ...
# 37  How many unique visitors to the Facebook Marke...
# 38  How many users were surveyed for their views o...
# 39  What were the subsections for the 2021 Highlig...
# 40  What are the subsections of the Workplaces sec...
# 41   What is the fact about Oceans shared on page 43?
# 42  What are the 4 facts shared in the Greenhouse ...
# 43  In the about netflix page, what are the mentio...
# 44  Who provided the testimonial on Netflix's Sust...
# 45  What are the Scope 1 and Scope 2 emission redu...
# 46  Who provided the testimonial on Netflix's Sust...
# 47         Can you provide the quote by Xiye Bastida?
# 48         Can you provide the quote by Aditi Sharma?
# 49  What 3 partner companies were spotlighted in t...
#
#                                    retrieved_contexts  \
# 0   [In 2022, we also released a preview version o...
# 1   [What’s next \nScope 3 emissions reduction \nM...
# 2   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 3   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 4   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 5   [Improving access \nto water \nWe continue to ...
# 6   [• • \na \n47\n | | | \nCommitments and progre...
# 7   [Leadership About Highlights How We Operate Wh...
# 8   [Leadership About Highlights How We Operate Wh...
# 9   [UN Sustainable Development Goal Apple’s suppo...
# 10  [Sometimes, that means joining \nregional coll...
# 11  [OUR APPROACH TO SUSTAINABILITY\nFor a Better ...
# 12  [Introduction Sustainability People Appendix \...
# 13  [31. In 2018, to align with industry best prac...
# 14  [Performance highlights\nThe following section...
# 15  [Education\nFor more than 40 years, we’ve work...
# 16  [Our approach\nWe believe that every business ...
# 17  [BUILDING BETTER DEVICES AND SERVICES\nTarget ...
# 18  [This guidance does not recognize existing ren...
# 19  [Employee Recruitment, Inclusion and Performan...
# 20  [GRI INDEX\nGRI 304 - Biodiversity\nGRI 103 Ma...
# 21  [IntroductionSustainability\nDriving Climate S...
# 22  [IntroductionSustainability\nDriving Climate S...
# 23  [IntroductionSustainability\nDriving Climate S...
# 24  [IntroductionSustainability\nDriving Climate S...
# 25  [IntroductionSustainability\nDriving Climate S...
# 26  [Tackling Climate  \nMisinformation\n \nClimat...
# 27  [Customer Shopping Experience\nWe have enabled...
# 28  [IntroductionSustainability\nDriving Climate S...
# 29  [Gross emissions\n   \nAvoided emissions\n  \n...
# 30  [Across our business, we released eight \nprod...
# 31  [Current\nyear\nBase\nyear\nTarget\nDiversion ...
# 32  [Growth and development\nWe want everyone to f...
# 33  [FY21 FY20 FY22\nCurrent yearBase year\n0M\n2M...
# 34  [IntroductionSustainability\nReducing Packagin...
# 35  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 36  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 37  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 38  [TACKLING CLIMATE MISINFORMATION\n“Misinformat...
# 39  [2021 Highlights\nCelebrating today.\nWorking ...
# 40  [Employees have several feedback routes. While...
# 41  [PUSHPIN FACTS\nFACT SOURCE LINK\nEarly warnin...
# 42  [18Netflix ESG Report 2022\n2022 SCOPE 1 AND 2...
# 43  [3Netflix ESG Report 2022\nA letter from our c...
# 44  [24Netflix ESG Report 2022\nThe film and telev...
# 45  [What’s next \nScope 3 emissions reduction \nM...
# 46  [24Netflix ESG Report 2022\nThe film and telev...
# 47  [49Netflix ESG Report 2022\nAs a women-led B-C...
# 48  [Employee Recruitment, Inclusion and Performan...
# 49  [Introduct ion Sustainability People \nIncreas...
#
#                                              response  \
# 0   The objective of the Carbon Call initiative is...
# 1   The three key areas that will enable the scale...
# 2   Microsoft provided water access to 225,389 peo...
# 3   The specific number of people in Indonesia pro...
# 4   Microsoft provided water access to 552,058 peo...
# 5   Microsoft provided water access to 309,921 peo...
# 6   According to Ecosystems Chart 1, Microsoft has...
# 7   The context provided does not include informat...
# 8   The context provided does not include informat...
# 9   The four commitments listed on page 66 are: \n...
# 10  The last key project listed under the Policy a...
# 11  The sub-sections for the "What We Create" sect...
# 12  The context does not provide information about...
# 13  The three highlights for the GHG emissions sec...
# 14  The percentage of waste from Google's offices ...
# 15  Apple focuses on empowering users with technol...
# 16  There is no listed key achievement for Google ...
# 17  Yes, Google reached its intended Waste target ...
# 18  The provided information does not specify the ...
# 19  The performance highlights for the Empowering ...
# 20  The provided information does not include a gl...
# 21  Details about Amazon's climate solutions can b...
# 22  Amazon intends to have all operations powered ...
# 23  Amazon has taken several actions to achieve it...
# 24  Amazon's Carbon Intensity values (grams of CO2...
# 25  Amazon's Total Carbon Footprint (MMT CO2e) for...
# 26  The report does not mention "The Climate Page ...
# 27  The provided information does not include deta...
# 28  Since 2020, 100% of corporate electricity use ...
# 29  The top two categories leading to the most avo...
# 30  Apple reduced plastic in packaging by 75 perce...
# 31  The provided information does not specify the ...
# 32  In 2021, staff spent more than 175,000 hours p...
# 33  The provided information does not include data...
# 34  The provided information does not include data...
# 35  3,000 pages and groups were removed for repeat...
# 36  Over 12 million pieces of misleading COVID-19 ...
# 37  There were 368,000 unique visitors to the Face...
# 38  The provided information does not specify the ...
# 39  The subsections for the 2021 Highlights were: ...
# 40  The subsections of the Workplaces section of t...
# 41  The fact about oceans shared is that they abso...
# 42  The context does not provide specific facts fr...
# 43  The mentioned highlights about the company inc...
# 44  The provided context does not include a testim...
# 45  The provided information does not specifically...
# 46  The provided context does not include a testim...
# 47  The provided information does not include a qu...
# 48  The provided context does not include a quote ...
# 49  The Inclusion and Diversity section does not s...
#
#                                             reference
# 0   The objective of Carbon Call is to unify the w...
# 1   1 Advancing AI solutions for greater climate i...
# 2                                             309,921
# 3                                             225,389
# 4                                              16,408
# 5                                                 340
# 6                                     4998 more acres
# 7   25%\nWe are reducing idle power consumption of...
# 8   100%\nOur key European and American distributi...
# 9   1. Using our voice on climate-related public p...
# 10  Making green jobs, skills, and entrepreneurshi...
# 11  Raising Awareness, Tackling Climate Misinforma...
# 12                Important, Very Important, Critical
# 13  Sure, they are: \n1. 65% cumulative GHG emissi...
# 14                                Sixty-four percent.
# 15  Sure! The Performance Highlights for Empowerin...
# 16  In 2017, Google became the first major company...
# 17  No, this target has not been met in 2021. Howe...
# 18                                             200000
# 19  The performance highlights for Empowering User...
# 20  Sure, here is the glossary:\nGlossary\nCFE: ca...
# 21  You can find information on driving climate so...
# 22  Amazon set the goal of becoming powered by 100...
# 23  Sure, here they are:\nActions\n90% Electricity...
# 24  Sure, here they are:\n2019: 122.8\n2020: 102.7...
# 25  Amazon's total footprint for the years 2019-20...
# 26                                         On page 14
# 27  Microsoft, jetBlue, Uber, Mercedez-Benz, Visa,...
# 28                             100% since April 2020.
# 29  The top two categories were: supplier clean en...
# 30                                                75%
# 31  More than 2 million metric tons of waste were ...
# 32                                       175000 hours
# 33  7600 million gallons of freshwater were saved ...
# 34  2021: 257000\n2020: 226000\n2019: 189000\n2018...
# 35                                               3000
# 36                                           12000000
# 37                                             368000
# 38                   76328 users across 31 countries.
# 39  1 Protecting People and Planet Through Respons...
# 40  1. Healthy and Sustainable Workplaces\n2. Offi...
# 41  Oceans absorb more than 90% ofthe heat that re...
# 42  1. CO2 emissions are increasing more than 250 ...
# 43  Public in 2002\nFounded in 1997\n231M paid mem...
# 44  Christiana Figueres,\nDiplomat and Architect o...
# 45  1 Energy Efficiency\n2 Renewable Energy (elect...
# 46  Elizabeth Sturcken,\nManaging Director, Enviro...
# 47  Young people like myself view Netflix as a che...
# 48  Through the Take Ten program, I got to learn a...
# 49  1. Black Economic Development Fund\n2. Hope Cr...

# %% [markdown]
# # 6. Calculation of RAGAS metrics
#
# The following 2 cells will execute the calculation of the RAGAS metrics. For this example we are going to calculate **faithfulness**, **context_precision**, and **context_recall**. To see all the RAGAS metrics and the full RAGAS documentation follow this link: [https://docs.ragas.io/en/latest/](https://docs.ragas.io/en/latest/)
#
# > *This process could take several minutes, even hours, depending on the rate limit (max tokens per minute) of the deployments used.*

# %%
evaluator_llm = LlamaIndexLLMWrapper(llm)
evaluator_embeddings = LlamaIndexEmbeddingsWrapper(embed_model)

# %%
# %%time

metrics = [
    Faithfulness(llm=evaluator_llm),
    ContextPrecision(llm=evaluator_llm),
    ContextRecall(llm=evaluator_llm)
]
ragas_evaluation_result = evaluate(
    dataset=ragas_evaluation_dataset,
    metrics=metrics,
    llm=evaluator_llm,
    embeddings=evaluator_embeddings,
    run_config=RunConfig(timeout=1800, max_wait=180, max_retries=20),
    show_progress=True,
    batch_size=20
)
# Out:
# Evaluating:   0%|          | 0/150 [00:00<?, ?it/s]
# Batch 1/8:   0%|          | 0/20 [00:00<?, ?it/s]
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 15 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.6087752933905917 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 15 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 16 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 6 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-08-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 6 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}.
# CPU times: user 5.67 s, sys: 313 ms, total: 5.98 s
# Wall time: 2min 41s

# %% [markdown]
# # 7. Data cleansing
#
# In some cases the RAGAS metric could return **null** values, the following cell cleans all the records with null metrics.

# %%
df_ragas_result = ragas_evaluation_result.to_pandas()

# Removing NULL values
df_ragas_result = df_ragas_result[(
    ~df_ragas_result['faithfulness'].isnull()
)&(
    ~df_ragas_result['context_precision'].isnull()
)&(
    ~df_ragas_result['context_recall'].isnull()
)].reset_index(drop=True)

print(f"Total records after data cleansing: {df_ragas_result.shape[0]}")
# Out:
# Total records after data cleansing: 50

# %% [markdown]
# # 8. Store the input calculated as a JSON file

# %%
df_ragas_result.to_json('./test-dataset.json', orient='records', indent=4)

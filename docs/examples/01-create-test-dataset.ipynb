# %% [markdown]
# `# TODO:`
#
# * Documentation of this notebook
# * Create another example with a different dataset

# %% [markdown]
# * 2.73 million of tokens from the llm
# * 3.19K of llm requests
# * 746.86K of tokens from the embeddings model
# * 212 embeddings requests
# * ~10 minutes for the creation of the index
# * ~60 minutes for the execution of the RAG to get the Bot answers
# * ~4 hours for the calculation of the RAGAS metrics

# %%
from llama_index.core.llama_dataset import download_llama_dataset
from dotenv import load_dotenv
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
import os
from llama_index.core import VectorStoreIndex, Settings
from ragas.metrics import (
    Faithfulness,
    AnswerRelevancy,
    ContextPrecision,
    ContextRecall
)
from ragas.llms import LlamaIndexLLMWrapper
from ragas.embeddings import LlamaIndexEmbeddingsWrapper
from ragas.dataset_schema import SingleTurnSample, EvaluationDataset
from ragas.evaluation import evaluate
from ragas.run_config import RunConfig

# %%
load_dotenv()
# Out:
# True

# %%
rag_dataset, documents = download_llama_dataset(
    llama_dataset_class="PaulGrahamEssayDataset", 
    download_dir="./data",
    show_progress=True
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Loading files: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.45file/s]

# %%
rag_dataset.to_pandas()
# Out:
#                                                 query  \
# 0   In the essay, the author mentions his early ex...
# 1   The author switched his major from philosophy ...
# 2   In the essay, the author discusses his initial...
# 3   The author mentions his shift of interest towa...
# 4   In the essay, the author mentions his interest...
# 5   The author discusses his decision to write a b...
# 6   In the essay, the author mentions a quick deci...
# 7   The author describes the atmosphere and practi...
# 8   In the essay, the author discusses his experie...
# 9   The author shares his work experience at a com...
# 10  In the essay, the author discusses his experie...
# 11  The author discusses the concept of a "signatu...
# 12  In the context of the essay, what was the auth...
# 13  According to the author's experience, why was ...
# 14  In the essay by Paul Graham, what was the init...
# 15  Describe the pivotal moment in the essay when ...
# 16  In the context of the essay, describe the thre...
# 17  The author mentions that their pricing strateg...
# 18  In the context of the essay, how did the autho...
# 19  Discuss the author's perspective on the import...
# 20  In the essay, the author mentions a transition...
# 21  The author experimented with a new kind of sti...
# 22  In the essay, the author discusses an idea for...
# 23  The author mentions a new dialect of Lisp that...
# 24  In the context of Paul Graham's essay, explain...
# 25  Analyze the shift in publishing essays from th...
# 26  In the essay by Paul Graham, he discusses his ...
# 27  Paul Graham mentions a strategy he used for wr...
# 28  In the essay by Paul Graham, describe the uniq...
# 29  Discuss the inception and initial implementati...
# 30  In the Summer Founders Program mentioned in th...
# 31  Discuss the role of Hacker News (HN) in the co...
# 32  In the essay, Paul Graham mentions a significa...
# 33  Discuss the transition of leadership at Y Comb...
# 34  In the context of the essay, why did the autho...
# 35  Discuss the significance of Lisp as a programm...
# 36  In the essay, the author discusses the develop...
# 37  The author mentions a significant life change ...
# 38  In the essay by Paul Graham, he discusses his ...
# 39  The author mentions several notes at the end o...
# 40  In the essay, Paul Graham discusses the concep...
# 41  Paul Graham uses the example of advanced alien...
# 42  In the essay by Paul Graham, he discusses the ...
# 43  Paul Graham mentions his experience of leaving...
#
#                                    reference_contexts  \
# 0   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 2   [I couldn't have put this into words when I wa...
# 3   [I couldn't have put this into words when I wa...
# 4   [So I looked around to see what I could salvag...
# 5   [So I looked around to see what I could salvag...
# 6   [I didn't want to drop out of grad school, but...
# 7   [I didn't want to drop out of grad school, but...
# 8   [We actually had one of those little stoves, f...
# 9   [We actually had one of those little stoves, f...
# 10  [But Interleaf still had a few years to live y...
# 11  [But Interleaf still had a few years to live y...
# 12  [Painting students were supposed to express th...
# 13  [Painting students were supposed to express th...
# 14  [Meanwhile I'd been hearing more and more abou...
# 15  [Meanwhile I'd been hearing more and more abou...
# 16  [In return for that and doing the initial lega...
# 17  [In return for that and doing the initial lega...
# 18  [Which meant being easy to use and inexpensive...
# 19  [Which meant being easy to use and inexpensive...
# 20  [But it didn't feel very valuable to me; I had...
# 21  [But it didn't feel very valuable to me; I had...
# 22  [It was as weird as it sounds. I resumed all m...
# 23  [It was as weird as it sounds. I resumed all m...
# 24  [Much to my surprise, the time I spent working...
# 25  [Much to my surprise, the time I spent working...
# 26  [It's not that unprestigious types of work are...
# 27  [It's not that unprestigious types of work are...
# 28  [As Jessica and I were walking home from dinne...
# 29  [As Jessica and I were walking home from dinne...
# 30  [[15] We got 225 applications for the Summer F...
# 31  [[15] We got 225 applications for the Summer F...
# 32  [When I was dealing with some urgent problem d...
# 33  [When I was dealing with some urgent problem d...
# 34  [Up till that point YC had been controlled by ...
# 35  [Up till that point YC had been controlled by ...
# 36  [It was missing a lot of things you'd want in ...
# 37  [It was missing a lot of things you'd want in ...
# 38  [Now that I could write essays again, I wrote ...
# 39  [Now that I could write essays again, I wrote ...
# 40  [People who see the responses to essays I writ...
# 41  [People who see the responses to essays I writ...
# 42  [[18] The worst thing about leaving YC was not...
# 43  [[18] The worst thing about leaving YC was not...
#
#                                      reference_answer reference_answer_by  \
# 0   The first computer the author used for program...          ai (gpt-4)
# 1   The two specific influences that led the autho...          ai (gpt-4)
# 2   The two main influences that initially drew th...          ai (gpt-4)
# 3   The author shifted his interest towards Lisp a...          ai (gpt-4)
# 4   The author in the essay is Paul Graham, who wa...          ai (gpt-4)
# 5   The author decided to write a book on Lisp hac...          ai (gpt-4)
# 6   The author decided to attempt writing his diss...          ai (gpt-4)
# 7   According to the author's account, the student...          ai (gpt-4)
# 8   In the essay, the author explains that paintin...          ai (gpt-4)
# 9   Interleaf, the company where the author worked...          ai (gpt-4)
# 10  The author was hired by Interleaf as a Lisp ha...          ai (gpt-4)
# 11  A "signature style" is a unique and identifiab...          ai (gpt-4)
# 12  The author initially perceived the World Wide ...          ai (gpt-4)
# 13  The author's idea of starting a company to put...          ai (gpt-4)
# 14  The initial idea for a startup by Paul Graham ...          ai (gpt-4)
# 15  The pivotal moment in the essay when the autho...          ai (gpt-4)
# 16  The three main parts of the software developed...          ai (gpt-4)
# 17  The author and his team priced their ecommerce...          ai (gpt-4)
# 18  The author's lack of business knowledge inadve...          ai (gpt-4)
# 19  The author believes that the growth rate is th...          ai (gpt-4)
# 20  In the essay, the author describes a significa...          ai (gpt-4)
# 21  The author's new approach to still life painti...          ai (gpt-4)
# 22  In the essay, the author discusses the idea of...          ai (gpt-4)
# 23  The author mentions that Lisp hackers often dr...          ai (gpt-4)
# 24  In Paul Graham's essay, his work on the new di...          ai (gpt-4)
# 25  In the essay, Paul Graham describes a signific...          ai (gpt-4)
# 26  In Paul Graham's essay, several key events and...          ai (gpt-4)
# 27  Paul Graham found that giving talks was an eff...          ai (gpt-4)
# 28  Y Combinator, as described in Paul Graham's es...          ai (gpt-4)
# 29  In Paul Graham's essay, the inception of the S...          ai (gpt-4)
# 30  The deal for startups in the Summer Founders P...          ai (gpt-4)
# 31  Hacker News (HN) was initially created as a ne...          ai (gpt-4)
# 32  In the essay, Robert Morris advised Paul Graha...          ai (gpt-4)
# 33  The transition of leadership at Y Combinator w...          ai (gpt-4)
# 34  The author decided to step away from YC to hel...          ai (gpt-4)
# 35  In the essay, the author describes Lisp as a p...          ai (gpt-4)
# 36  The author developed a new programming languag...          ai (gpt-4)
# 37  The significant life change that occurred duri...          ai (gpt-4)
# 38  In Paul Graham's essay, he reflects on his own...          ai (gpt-4)
# 39  Without the full context of the essay, it's di...          ai (gpt-4)
# 40  Yes, Paul Graham discusses the concept of cust...          ai (gpt-4)
# 41  Paul Graham uses the analogy of advanced alien...          ai (gpt-4)
# 42  In the essay, Paul Graham uses the concept of ...          ai (gpt-4)
# 43  Paul Graham describes his experience of leavin...          ai (gpt-4)
#
#       query_by
# 0   ai (gpt-4)
# 1   ai (gpt-4)
# 2   ai (gpt-4)
# 3   ai (gpt-4)
# 4   ai (gpt-4)
# 5   ai (gpt-4)
# 6   ai (gpt-4)
# 7   ai (gpt-4)
# 8   ai (gpt-4)
# 9   ai (gpt-4)
# 10  ai (gpt-4)
# 11  ai (gpt-4)
# 12  ai (gpt-4)
# 13  ai (gpt-4)
# 14  ai (gpt-4)
# 15  ai (gpt-4)
# 16  ai (gpt-4)
# 17  ai (gpt-4)
# 18  ai (gpt-4)
# 19  ai (gpt-4)
# 20  ai (gpt-4)
# 21  ai (gpt-4)
# 22  ai (gpt-4)
# 23  ai (gpt-4)
# 24  ai (gpt-4)
# 25  ai (gpt-4)
# 26  ai (gpt-4)
# 27  ai (gpt-4)
# 28  ai (gpt-4)
# 29  ai (gpt-4)
# 30  ai (gpt-4)
# 31  ai (gpt-4)
# 32  ai (gpt-4)
# 33  ai (gpt-4)
# 34  ai (gpt-4)
# 35  ai (gpt-4)
# 36  ai (gpt-4)
# 37  ai (gpt-4)
# 38  ai (gpt-4)
# 39  ai (gpt-4)
# 40  ai (gpt-4)
# 41  ai (gpt-4)
# 42  ai (gpt-4)
# 43  ai (gpt-4)

# %%
embed_model = AzureOpenAIEmbedding(
    model='text-embedding-3-small',
    api_key=os.environ['OPENAI_API_KEY'],
    api_version=os.environ['OPENAI_API_VERSION'],
    azure_endpoint=os.environ['AZURE_OPENAI_ENDPOINT']
)

llm = AzureOpenAI(
    engine="gpt-4o", 
    model="gpt-4o", 
    temperature=0.0,
    api_key=os.environ['OPENAI_API_KEY'],
    api_version=os.environ['OPENAI_API_VERSION'],
    azure_endpoint=os.environ['AZURE_OPENAI_ENDPOINT']
)

# %%
Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(
    documents=documents,
    show_progress=True
)
query_engine = index.as_query_engine()
# Out:
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/22 [00:00<?, ?it/s]

# %%
predictions = rag_dataset.make_predictions_with(
    predictor = query_engine,
    show_progress = True,
    batch_size = 20
)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [08:24<00:00, 25.24s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [5:01:21<00:00, 904.08s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [43:48<00:00, 657.25s/it]

# %%
list_of_samples = []

for idx in range(len(rag_dataset.examples)):
    list_of_samples.append(
        SingleTurnSample (
            user_input = rag_dataset.examples[idx].query,
            reference = rag_dataset.examples[idx].reference_answer,
            response = predictions.predictions[idx].response,
            retrieved_contexts = predictions.predictions[idx].contexts
        )
    )

ragas_evaluation_dataset = EvaluationDataset(list_of_samples)
ragas_evaluation_dataset.to_pandas().sample(5)
# Out:
#                                            user_input  \
# 0   In the essay, the author mentions his early ex...
# 42  In the essay by Paul Graham, he discusses the ...
# 18  In the context of the essay, how did the autho...
# 41  Paul Graham uses the example of advanced alien...
# 26  In the essay by Paul Graham, he discusses his ...
#
#                                    retrieved_contexts  \
# 0   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 42  [[17] Another problem with HN was a bizarre ed...
# 18  [I kept the code tight and didn't have to inte...
# 41  [[17] Another problem with HN was a bizarre ed...
# 26  [One of the most conspicuous patterns I've not...
#
#                                              response  \
# 0   The first computer the author used for program...
# 42  In the essay, Paul Graham uses the example of ...
# 18  The author's lack of business knowledge inadve...
# 41  Paul Graham uses the analogy of advanced alien...
# 26  In the essay, several key events and individua...
#
#                                             reference
# 0   The first computer the author used for program...
# 42  In the essay, Paul Graham uses the concept of ...
# 18  The author's lack of business knowledge inadve...
# 41  Paul Graham uses the analogy of advanced alien...
# 26  In Paul Graham's essay, several key events and...

# %%
evaluator_llm = LlamaIndexLLMWrapper(llm)
evaluator_embeddings = LlamaIndexEmbeddingsWrapper(embed_model)

# %%
metrics = [
    Faithfulness(llm=evaluator_llm),
    ContextPrecision(llm=evaluator_llm),
    ContextRecall(llm=evaluator_llm)
]
ragas_evaluation_result = evaluate(
    dataset=ragas_evaluation_dataset,
    metrics=metrics,
    llm=evaluator_llm,
    embeddings=evaluator_embeddings,
    run_config=RunConfig(timeout=1800, max_wait=180, max_retries=20),
    show_progress=True,
    batch_size=20
)
# Out:
# Evaluating:   0%|          | 0/132 [00:00<?, ?it/s]
# Batch 1/7:   0%|          | 0/20 [00:00<?, ?it/s]
# Exception raised in Job[101]: AttributeError('StringIO' object has no attribute 'classifications')

# %%
df_ragas_result = ragas_evaluation_result.to_pandas()

# Removing NULL values
df_ragas_result = df_ragas_result[(
    ~df_ragas_result['faithfulness'].isnull()
)&(
    ~df_ragas_result['context_precision'].isnull()
)&(
    ~df_ragas_result['context_recall'].isnull()
)].reset_index(drop=True)

df_ragas_result
# Out:
#                                            user_input  \
# 0   In the essay, the author mentions his early ex...
# 1   The author switched his major from philosophy ...
# 2   In the essay, the author discusses his initial...
# 3   The author mentions his shift of interest towa...
# 4   In the essay, the author mentions his interest...
# 5   The author discusses his decision to write a b...
# 6   In the essay, the author mentions a quick deci...
# 7   The author describes the atmosphere and practi...
# 8   In the essay, the author discusses his experie...
# 9   The author shares his work experience at a com...
# 10  In the essay, the author discusses his experie...
# 11  The author discusses the concept of a "signatu...
# 12  In the context of the essay, what was the auth...
# 13  According to the author's experience, why was ...
# 14  In the essay by Paul Graham, what was the init...
# 15  Describe the pivotal moment in the essay when ...
# 16  In the context of the essay, describe the thre...
# 17  The author mentions that their pricing strateg...
# 18  In the context of the essay, how did the autho...
# 19  Discuss the author's perspective on the import...
# 20  In the essay, the author mentions a transition...
# 21  The author experimented with a new kind of sti...
# 22  In the essay, the author discusses an idea for...
# 23  The author mentions a new dialect of Lisp that...
# 24  In the context of Paul Graham's essay, explain...
# 25  Analyze the shift in publishing essays from th...
# 26  In the essay by Paul Graham, he discusses his ...
# 27  Paul Graham mentions a strategy he used for wr...
# 28  In the essay by Paul Graham, describe the uniq...
# 29  Discuss the inception and initial implementati...
# 30  In the Summer Founders Program mentioned in th...
# 31  Discuss the role of Hacker News (HN) in the co...
# 32  In the essay, Paul Graham mentions a significa...
# 33  In the context of the essay, why did the autho...
# 34  Discuss the significance of Lisp as a programm...
# 35  In the essay, the author discusses the develop...
# 36  The author mentions a significant life change ...
# 37  In the essay by Paul Graham, he discusses his ...
# 38  The author mentions several notes at the end o...
# 39  In the essay, Paul Graham discusses the concep...
# 40  Paul Graham uses the example of advanced alien...
# 41  In the essay by Paul Graham, he discusses the ...
# 42  Paul Graham mentions his experience of leaving...
#
#                                    retrieved_contexts  \
# 0   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 2   [All that seemed left for philosophy were edge...
# 3   [All that seemed left for philosophy were edge...
# 4   [Its brokenness did, as so often happens, gene...
# 5   [All that seemed left for philosophy were edge...
# 6   [Its brokenness did, as so often happens, gene...
# 7   [If he even knew about the strange classes I w...
# 8   [The students and faculty in the painting depa...
# 9   [The students and faculty in the painting depa...
# 10  [The students and faculty in the painting depa...
# 11  [I wanted to go back to RISD, but I was now br...
# 12  [But about halfway through the summer I realiz...
# 13  [After I moved to New York I became her de fac...
# 14  [Horrified at the prospect of having my inbox ...
# 15  [After I moved to New York I became her de fac...
# 16  [Now we felt like we were really onto somethin...
# 17  [Now we felt like we were really onto somethin...
# 18  [I kept the code tight and didn't have to inte...
# 19  [I kept the code tight and didn't have to inte...
# 20  [A company with just a handful of employees wo...
# 21  [But alas it was more like the Accademia than ...
# 22  [I stuck it out for a few more months, then in...
# 23  [It had already eaten Arc, and was in the proc...
# 24  [It had already eaten Arc, and was in the proc...
# 25  [But about halfway through the summer I realiz...
# 26  [One of the most conspicuous patterns I've not...
# 27  [One of the most conspicuous patterns I've not...
# 28  [Horrified at the prospect of having my inbox ...
# 29  [Horrified at the prospect of having my inbox ...
# 30  [Horrified at the prospect of having my inbox ...
# 31  [We'd use the building I owned in Cambridge as...
# 32  [It was originally meant to be a news aggregat...
# 33  [It had already eaten Arc, and was in the proc...
# 34  [All that seemed left for philosophy were edge...
# 35  [All that seemed left for philosophy were edge...
# 36  [It had already eaten Arc, and was in the proc...
# 37  [But about halfway through the summer I realiz...
# 38  [But about halfway through the summer I realiz...
# 39  [[17] Another problem with HN was a bizarre ed...
# 40  [[17] Another problem with HN was a bizarre ed...
# 41  [[17] Another problem with HN was a bizarre ed...
# 42  [But when the software is an online store buil...
#
#                                              response  \
# 0   The first computer the author used for program...
# 1   The author developed an interest in AI due to ...
# 2   The author's initial interest in AI was influe...
# 3   The author shifted his interest towards Lisp b...
# 4   During his time in grad school, the author att...
# 5   The author decided to write a book on Lisp hac...
# 6   The author made a quick decision to attempt to...
# 7   The author describes the atmosphere at the Acc...
# 8   The author describes painting still lives as d...
# 9   Interleaf had added a unique feature to their ...
# 10  The author worked at Interleaf as a Lisp hacke...
# 11  A signature style in painting is a distinctive...
# 12  The author's initial perception of the World W...
# 13  The author's idea of starting a company to put...
# 14  The essay does not specify an initial idea for...
# 15  The pivotal moment occurred when the author, w...
# 16  The software developed for the online store bu...
# 17  The pricing strategy for the ecommerce softwar...
# 18  The author's lack of business knowledge inadve...
# 19  The author emphasizes the importance of growth...
# 20  After the sale of his company to Yahoo, the au...
# 21  The context does not provide specific details ...
# 22  The author discusses the concept of a web appl...
# 23  The author does not explicitly mention reasons...
# 24  Paul Graham's work on the new dialect of Lisp,...
# 25  Paul Graham views the shift from the print era...
# 26  In the essay, several key events and individua...
# 27  Paul Graham used the strategy of giving talks ...
# 28  Y Combinator adopted a unique approach to inve...
# 29  The Summer Founders Program was conceived as a...
# 30  In the Summer Founders Program, the deal for s...
# 31  Hacker News (HN) played a dual role in the con...
# 32  Robert Morris advised Paul Graham to ensure th...
# 33  The author decided to step away from YC becaus...
# 34  Lisp is portrayed as a significant programming...
# 35  The essay does not specifically mention the de...
# 36  During the development of the programming lang...
# 37  In the essay, Paul Graham illustrates how pers...
# 38  One of the notes discusses the challenge of ma...
# 39  Paul Graham discusses how customs can continue...
# 40  Paul Graham uses the analogy of advanced alien...
# 41  In the essay, Paul Graham uses the example of ...
# 42  Paul Graham describes the experience of leavin...
#
#                                             reference  faithfulness  \
# 0   The first computer the author used for program...      1.000000
# 1   The two specific influences that led the autho...      1.000000
# 2   The two main influences that initially drew th...      1.000000
# 3   The author shifted his interest towards Lisp a...      1.000000
# 4   The author in the essay is Paul Graham, who wa...      0.642857
# 5   The author decided to write a book on Lisp hac...      0.615385
# 6   The author decided to attempt writing his diss...      1.000000
# 7   According to the author's account, the student...      1.000000
# 8   In the essay, the author explains that paintin...      0.916667
# 9   Interleaf, the company where the author worked...      0.500000
# 10  The author was hired by Interleaf as a Lisp ha...      1.000000
# 11  A "signature style" is a unique and identifiab...      1.000000
# 12  The author initially perceived the World Wide ...      1.000000
# 13  The author's idea of starting a company to put...      0.875000
# 14  The initial idea for a startup by Paul Graham ...      1.000000
# 15  The pivotal moment in the essay when the autho...      1.000000
# 16  The three main parts of the software developed...      0.777778
# 17  The author and his team priced their ecommerce...      1.000000
# 18  The author's lack of business knowledge inadve...      1.000000
# 19  The author believes that the growth rate is th...      0.789474
# 20  In the essay, the author describes a significa...      1.000000
# 21  The author's new approach to still life painti...      0.875000
# 22  In the essay, the author discusses the idea of...      0.666667
# 23  The author mentions that Lisp hackers often dr...      0.000000
# 24  In Paul Graham's essay, his work on the new di...      0.785714
# 25  In the essay, Paul Graham describes a signific...      1.000000
# 26  In Paul Graham's essay, several key events and...      1.000000
# 27  Paul Graham found that giving talks was an eff...      0.500000
# 28  Y Combinator, as described in Paul Graham's es...      1.000000
# 29  In Paul Graham's essay, the inception of the S...      0.833333
# 30  The deal for startups in the Summer Founders P...      1.000000
# 31  Hacker News (HN) was initially created as a ne...      0.916667
# 32  In the essay, Robert Morris advised Paul Graha...      1.000000
# 33  The author decided to step away from YC to hel...      0.933333
# 34  In the essay, the author describes Lisp as a p...      0.941176
# 35  The author developed a new programming languag...      1.000000
# 36  The significant life change that occurred duri...      0.875000
# 37  In Paul Graham's essay, he reflects on his own...      1.000000
# 38  Without the full context of the essay, it's di...      0.636364
# 39  Yes, Paul Graham discusses the concept of cust...      0.928571
# 40  Paul Graham uses the analogy of advanced alien...      1.000000
# 41  In the essay, Paul Graham uses the concept of ...      0.818182
# 42  Paul Graham describes his experience of leavin...      0.833333
#
#     context_precision  context_recall
# 0                 1.0        1.000000
# 1                 1.0        1.000000
# 2                 1.0        1.000000
# 3                 1.0        1.000000
# 4                 1.0        0.866667
# 5                 1.0        1.000000
# 6                 0.5        1.000000
# 7                 1.0        1.000000
# 8                 1.0        1.000000
# 9                 0.0        0.571429
# 10                0.0        0.200000
# 11                1.0        1.000000
# 12                0.5        0.750000
# 13                1.0        1.000000
# 14                0.0        0.000000
# 15                1.0        1.000000
# 16                1.0        1.000000
# 17                1.0        1.000000
# 18                1.0        0.875000
# 19                1.0        1.000000
# 20                1.0        0.944444
# 21                0.0        0.000000
# 22                1.0        1.000000
# 23                0.0        0.000000
# 24                0.5        0.625000
# 25                1.0        1.000000
# 26                1.0        1.000000
# 27                1.0        1.000000
# 28                1.0        0.916667
# 29                1.0        1.000000
# 30                0.5        1.000000
# 31                1.0        0.750000
# 32                1.0        1.000000
# 33                1.0        1.000000
# 34                0.5        0.545455
# 35                0.0        0.000000
# 36                0.5        1.000000
# 37                1.0        0.250000
# 38                0.0        0.000000
# 39                0.5        1.000000
# 40                1.0        1.000000
# 41                1.0        1.000000
# 42                0.0        0.000000

# %%
df_ragas_result.to_json('./test-dataset.json', orient='records', indent=4)

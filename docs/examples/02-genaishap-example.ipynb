# %%
import pandas as pd
from gaishap import Featurizer
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
df_test_dataset = pd.read_json('./test-dataset.json', orient='records')
df_test_dataset.sample(5)
# Out:
#                                             user_input  \
# 97   What risk factors were outlined by Microsoft i...
# 168  Analyze how NVIDIA's reported tax rate in the ...
# 63   Are there any significant changes in Amazon's ...
# 94   In the Q2 2023 10-Q, did Microsoft announce an...
# 123  What was the effective tax rate for Intel as s...
#
#                                     retrieved_contexts  \
# 97   [PART IIItem 1A\n \nBesides software developme...
# 168  [NVIDIA CORPORATION AND SUBSIDIARIES\nNOTES TO...
# 63   [Table of Contents\npayments of short-term deb...
# 94   [PART IItem 2\n \nThe following table outlines...
# 123  [Table of Contents\nSee "Non-GAAP Financial Me...
#
#                                               response  \
# 97   In the Q3 2023 10-Q, Microsoft outlined severa...
# 168  NVIDIA's reported tax rate in the most recent ...
# 63   There are notable changes in Amazon's debt str...
# 94   In the Q2 2023 10-Q, Microsoft did not announc...
# 123  The effective tax rate for Intel in the most r...
#
#                                              reference  faithfulness  \
# 97   The risk factors outlined by Microsoft in the ...      0.916667
# 168  The reported tax rate for NVIDIA in the most r...      1.000000
# 63   Yes, there are significant changes in Amazon's...      0.888889
# 94   In the Q2 2023 10-Q, Microsoft did not announc...      0.500000
# 123  The effective tax rate for Intel for the quart...      1.000000
#
#      context_precision  context_recall
# 97                 0.0        0.000000
# 168                1.0        0.909091
# 63                 0.0        0.000000
# 94                 1.0        0.500000
# 123                0.0        0.000000

# %%
featurizer = Featurizer.from_pandas(df_test_dataset)
featurizer.create_features_using_azure_openai(deployment_name="gpt-4o")
print(featurizer.features.model_dump_json(indent=4))
# Out:
# {
#     "features": [
#         {
#             "feature": "there_is_any_company_indentified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_companies_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "there_is_any_business_segment_indentified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_business_segments_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "there_is_any_financial_metric_identified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_if_financial_metrics_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "there_is_any_specific_quarter_identified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_quarters_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "is_a_comparison_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_trends_or_changes_over_time",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_identification_of_factors_or_insights",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_related_to_the_notes_section",
#             "ftype": "boolean"
#         }
#     ]
# }

# %%
featurizer.fill_out_features_using_azure_openai(deployment_name="gpt-4o")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
df_features = featurizer.to_pandas()
df_features.sample(5)
# Out:
#      there_is_any_company_indentified_in_the_question  \
# 139                                              True
# 69                                               True
# 68                                               True
# 75                                               True
# 45                                               True
#
#     list_of_companies_identified_in_the_question  \
# 139                                     [Amazon]
# 69                                       [Apple]
# 68                                       [Apple]
# 75                                       [Apple]
# 45                                   [Microsoft]
#
#      there_is_any_business_segment_indentified_in_the_question  \
# 139                                              False
# 69                                               False
# 68                                               False
# 75                                               False
# 45                                                True
#
#     list_of_business_segments_identified_in_the_question  \
# 139                                                 []
# 69                                                  []
# 68                                                  []
# 75                                                  []
# 45                                    [Cloud Services]
#
#      there_is_any_financial_metric_identified_in_the_question  \
# 139                                              False
# 69                                                True
# 68                                                True
# 75                                                True
# 45                                                True
#
#     list_if_financial_metrics_identified_in_the_question  \
# 139                                                 []
# 69                       [operating expenses, revenue]
# 68                                      [gross margin]
# 75                          [research and development]
# 45                                           [revenue]
#
#      there_is_any_specific_quarter_identified_in_the_question  \
# 139                                               True
# 69                                                True
# 68                                                True
# 75                                                True
# 45                                               False
#
#     list_of_quarters_identified_in_the_question  is_a_comparison_question  \
# 139                                   [Q2 2023]                     False
# 69                                    [Q1 2023]                      True
# 68                                [latest 10-Q]                     False
# 75                                    [Q1 2023]                     False
# 45                                           []                     False
#
#      is_a_question_about_trends_or_changes_over_time  \
# 139                                            False
# 69                                             False
# 68                                             False
# 75                                             False
# 45                                              True
#
#      is_a_question_about_identification_of_factors_or_insights  \
# 139                                               True
# 69                                               False
# 68                                               False
# 75                                                True
# 45                                               False
#
#      is_a_question_related_to_the_notes_section
# 139                                       False
# 69                                        False
# 68                                        False
# 75                                        False
# 45                                        False

# %%
df_features.to_json('./test-features.json', orient='records', indent=4)

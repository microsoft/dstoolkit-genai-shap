# %% [markdown]
# <h1 align="center">
#     <img
#         src="../img/logo_white_bg.jpeg"
#         width="200"
#         border="1" />
# </h1>
# <h1 align="center">
#     <b>GenAISHAP</b>
# </h1>
# <h4 align="center">
#     <i>Explanations for Generative AI, LLM-and-SLM-Based, Solutions</i> ⚡️
# </h4>
#
#
#
# Generative AI SHAP (GenAISHAP) is a python library that supports the creation of explanations to the metrics obtained for solutions based on LLMs (Large Language Models) or SLMs (Small Language Models).
#
# The previous notebook showed an example of how to create the **Input** for ***GenAISHAP***, which is a simple Pandas DataFrame with the evaluation dataset. A pandas Dataframe like the following was produced and stored as a JSON file:
#
# <img src="../img/input_example.png" width="1200" />
#
# > The column `user_input` will be used to refer to the user prompt, and the columns `faithfulness`, `context_precision` and `context_recall` will be used as metric columns since those columns are numerical.
# >
# > The other columns, `retrieved_contexts`, `response`, and `reference` are not needed for **GenAISHAP** but were required for the calculation of the metrics.
#
# ***GenAISHAP*** works as follows.  ***GenAISHAP*** will create regression models, which we call them **black-box models**, for each of the metrics and will use those black-box models to produce explanations for each metric. The models are created from features extracted from the provided questions. Those **question features** could be generated automatically, using a tool, named **Featurizer** incorporated in the library or they can be manually created.
#
# This notebook explains how to use the **Featurizer** tool.

# %%
import pandas as pd
from genaishap import Featurizer
from dotenv import load_dotenv

# %% [markdown]
# # 1. Load input and set environment variables
#
# The **Featurizer** tool uses an LLM to produce the features and its corresponding values per instance sample. That is the reason we need to load the environment variable here in this notebook.  The loaded dataset is the one was created in the previous notebook.

# %%
load_dotenv()
# Out:
# True

# %%
df_test_dataset = pd.read_json('./test-dataset.json', orient='records')
df_test_dataset
# Out:
#                                            user_input  \
# 0   What is the objective of the Carbon Call initi...
# 1   What are the three key areas that will enable ...
# 2   How many people in India did Microsoft provide...
# 3   How many people in Indonesia did Microsoft pro...
# 4   How many people in Brazil did Microsoft provid...
# 5   How many people in Mexico did Microsoft provid...
# 6   How many more acres of land does Microsoft nee...
# 7   What key insight was listed in page 56 of the ...
# 8   What key insight was listed in page 61 of the ...
# 9    What are the four commitments listed on page 66?
# 10  What is the last Key project listed under Poli...
# 11  What are the sub sections for "What We Create"...
# 12  What are the category labels for each topic in...
# 13  Can you provide for me the three highlights fo...
# 14  What percentage of waste from Google's offices...
# 15  Can you present me with the performance highli...
# 16  What was the listed key achievement regarding ...
# 17  Did Google reach its intended Waste target und...
# 18  How many EV charging locations were there on G...
# 19  On what page of the report can I find the perf...
# 20  Can you please provide for me the glossary of ...
# 21  On what page can I find details about Amazons ...
# 22  For the listed Renewable Energy goals, by when...
# 23  Can you provide the Actions taken by Amazon fo...
# 24  What were Amazon's Carbon Intesity values in (...
# 25  What were Amazon's Total Carbon Footprint (MMT...
# 26  On what page can of the report can I find info...
# 27  What household brands were featured in the in ...
# 28  What percentage of corporate emissions since 2...
# 29  In Apple's comprehensive carbon footprint, wha...
# 30  By what percentage did Apple reduce plastic in...
# 31  How many metric tons of waste were redirected ...
# 32  In 2021, how many hours were spent by staff ac...
# 33  How many millions of gallons of freshwater was...
# 34  What were the Total Packaging resources used i...
# 35  How many pages and groups were removed for rep...
# 36  How many artifacts were removed from Facebook ...
# 37  How many unique visitors to the Facebook Marke...
# 38  How many users were surveyed for their views o...
# 39  What were the subsections for the 2021 Highlig...
# 40  What are the subsections of the Workplaces sec...
# 41   What is the fact about Oceans shared on page 43?
# 42  What are the 4 facts shared in the Greenhouse ...
# 43  In the about netflix page, what are the mentio...
# 44  Who provided the testimonial on Netflix's Sust...
# 45  What are the Scope 1 and Scope 2 emission redu...
# 46  Who provided the testimonial on Netflix's Sust...
# 47         Can you provide the quote by Xiye Bastida?
# 48         Can you provide the quote by Aditi Sharma?
# 49  What 3 partner companies were spotlighted in t...
#
#                                    retrieved_contexts  \
# 0   [In 2022, we also released a preview version o...
# 1   [What’s next \nScope 3 emissions reduction \nM...
# 2   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 3   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 4   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 5   [Improving access \nto water \nWe continue to ...
# 6   [• • \na \n47\n | | | \nCommitments and progre...
# 7   [Leadership About Highlights How We Operate Wh...
# 8   [Leadership About Highlights How We Operate Wh...
# 9   [UN Sustainable Development Goal Apple’s suppo...
# 10  [Sometimes, that means joining \nregional coll...
# 11  [OUR APPROACH TO SUSTAINABILITY\nFor a Better ...
# 12  [Introduction Sustainability People Appendix \...
# 13  [31. In 2018, to align with industry best prac...
# 14  [Performance highlights\nThe following section...
# 15  [Education\nFor more than 40 years, we’ve work...
# 16  [Our approach\nWe believe that every business ...
# 17  [BUILDING BETTER DEVICES AND SERVICES\nTarget ...
# 18  [This guidance does not recognize existing ren...
# 19  [Employee Recruitment, Inclusion and Performan...
# 20  [GRI INDEX\nGRI 304 - Biodiversity\nGRI 103 Ma...
# 21  [IntroductionSustainability\nDriving Climate S...
# 22  [IntroductionSustainability\nDriving Climate S...
# 23  [IntroductionSustainability\nDriving Climate S...
# 24  [IntroductionSustainability\nDriving Climate S...
# 25  [IntroductionSustainability\nDriving Climate S...
# 26  [Tackling Climate  \nMisinformation\n \nClimat...
# 27  [Customer Shopping Experience\nWe have enabled...
# 28  [IntroductionSustainability\nDriving Climate S...
# 29  [Gross emissions\n   \nAvoided emissions\n  \n...
# 30  [Across our business, we released eight \nprod...
# 31  [Current\nyear\nBase\nyear\nTarget\nDiversion ...
# 32  [Growth and development\nWe want everyone to f...
# 33  [FY21 FY20 FY22\nCurrent yearBase year\n0M\n2M...
# 34  [IntroductionSustainability\nReducing Packagin...
# 35  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 36  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 37  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 38  [TACKLING CLIMATE MISINFORMATION\n“Misinformat...
# 39  [2021 Highlights\nCelebrating today.\nWorking ...
# 40  [Employees have several feedback routes. While...
# 41  [PUSHPIN FACTS\nFACT SOURCE LINK\nEarly warnin...
# 42  [18Netflix ESG Report 2022\n2022 SCOPE 1 AND 2...
# 43  [3Netflix ESG Report 2022\nA letter from our c...
# 44  [24Netflix ESG Report 2022\nThe film and telev...
# 45  [What’s next \nScope 3 emissions reduction \nM...
# 46  [24Netflix ESG Report 2022\nThe film and telev...
# 47  [49Netflix ESG Report 2022\nAs a women-led B-C...
# 48  [Employee Recruitment, Inclusion and Performan...
# 49  [Introduct ion Sustainability People \nIncreas...
#
#                                              response  \
# 0   The objective of the Carbon Call initiative is...
# 1   The three key areas that will enable the scale...
# 2   Microsoft provided water access to 225,389 peo...
# 3   The specific number of people in Indonesia pro...
# 4   Microsoft provided water access to 552,058 peo...
# 5   Microsoft provided water access to 309,921 peo...
# 6   According to Ecosystems Chart 1, Microsoft has...
# 7   The context provided does not include informat...
# 8   The context provided does not include informat...
# 9   The four commitments listed on page 66 are: \n...
# 10  The last key project listed under the Policy a...
# 11  The sub-sections for the "What We Create" sect...
# 12  The context does not provide information about...
# 13  The three highlights for the GHG emissions sec...
# 14  The percentage of waste from Google's offices ...
# 15  Apple focuses on empowering users with technol...
# 16  There is no listed key achievement for Google ...
# 17  Yes, Google reached its intended Waste target ...
# 18  The provided information does not specify the ...
# 19  The performance highlights for the Empowering ...
# 20  The provided information does not include a gl...
# 21  Details about Amazon's climate solutions can b...
# 22  Amazon intends to have all operations powered ...
# 23  Amazon has taken several actions to achieve it...
# 24  Amazon's Carbon Intensity values (grams of CO2...
# 25  Amazon's Total Carbon Footprint (MMT CO2e) for...
# 26  The report does not mention "The Climate Page ...
# 27  The provided information does not include deta...
# 28  Since 2020, 100% of corporate electricity use ...
# 29  The top two categories leading to the most avo...
# 30  Apple reduced plastic in packaging by 75 perce...
# 31  The provided information does not specify the ...
# 32  In 2021, staff spent more than 175,000 hours p...
# 33  The provided information does not include data...
# 34  The provided information does not include data...
# 35  3,000 pages and groups were removed for repeat...
# 36  Over 12 million pieces of misleading COVID-19 ...
# 37  There were 368,000 unique visitors to the Face...
# 38  The provided information does not specify the ...
# 39  The subsections for the 2021 Highlights were: ...
# 40  The subsections of the Workplaces section of t...
# 41  The fact about oceans shared is that they abso...
# 42  The context does not provide specific facts fr...
# 43  The mentioned highlights about the company inc...
# 44  The provided context does not include a testim...
# 45  The provided information does not specifically...
# 46  The provided context does not include a testim...
# 47  The provided information does not include a qu...
# 48  The provided context does not include a quote ...
# 49  The Inclusion and Diversity section does not s...
#
#                                             reference  faithfulness  \
# 0   The objective of Carbon Call is to unify the w...      1.000000
# 1   1 Advancing AI solutions for greater climate i...      0.750000
# 2                                             309,921      0.000000
# 3                                             225,389      1.000000
# 4                                              16,408      1.000000
# 5                                                 340      0.000000
# 6                                     4998 more acres      0.800000
# 7   25%\nWe are reducing idle power consumption of...      1.000000
# 8   100%\nOur key European and American distributi...      1.000000
# 9   1. Using our voice on climate-related public p...      0.250000
# 10  Making green jobs, skills, and entrepreneurshi...      0.500000
# 11  Raising Awareness, Tackling Climate Misinforma...      0.888889
# 12                Important, Very Important, Critical      1.000000
# 13  Sure, they are: \n1. 65% cumulative GHG emissi...      0.857143
# 14                                Sixty-four percent.      1.000000
# 15  Sure! The Performance Highlights for Empowerin...      0.900000
# 16  In 2017, Google became the first major company...      1.000000
# 17  No, this target has not been met in 2021. Howe...      0.500000
# 18                                             200000      1.000000
# 19  The performance highlights for Empowering User...      1.000000
# 20  Sure, here is the glossary:\nGlossary\nCFE: ca...      1.000000
# 21  You can find information on driving climate so...      0.000000
# 22  Amazon set the goal of becoming powered by 100...      1.000000
# 23  Sure, here they are:\nActions\n90% Electricity...      1.000000
# 24  Sure, here they are:\n2019: 122.8\n2020: 102.7...      1.000000
# 25  Amazon's total footprint for the years 2019-20...      1.000000
# 26                                         On page 14      1.000000
# 27  Microsoft, jetBlue, Uber, Mercedez-Benz, Visa,...      1.000000
# 28                             100% since April 2020.      0.000000
# 29  The top two categories were: supplier clean en...      1.000000
# 30                                                75%      1.000000
# 31  More than 2 million metric tons of waste were ...      1.000000
# 32                                       175000 hours      1.000000
# 33  7600 million gallons of freshwater were saved ...      1.000000
# 34  2021: 257000\n2020: 226000\n2019: 189000\n2018...      1.000000
# 35                                               3000      0.000000
# 36                                           12000000      1.000000
# 37                                             368000      1.000000
# 38                   76328 users across 31 countries.      1.000000
# 39  1 Protecting People and Planet Through Respons...      1.000000
# 40  1. Healthy and Sustainable Workplaces\n2. Offi...      0.750000
# 41  Oceans absorb more than 90% ofthe heat that re...      0.500000
# 42  1. CO2 emissions are increasing more than 250 ...      1.000000
# 43  Public in 2002\nFounded in 1997\n231M paid mem...      1.000000
# 44  Christiana Figueres,\nDiplomat and Architect o...      1.000000
# 45  1 Energy Efficiency\n2 Renewable Energy (elect...      0.583333
# 46  Elizabeth Sturcken,\nManaging Director, Enviro...      1.000000
# 47  Young people like myself view Netflix as a che...      1.000000
# 48  Through the Take Ten program, I got to learn a...      1.000000
# 49  1. Black Economic Development Fund\n2. Hope Cr...      0.000000
#
#     context_precision  context_recall
# 0                 1.0        1.000000
# 1                 0.0        0.666667
# 2                 0.0        0.000000
# 3                 1.0        0.000000
# 4                 1.0        0.000000
# 5                 0.0        1.000000
# 6                 1.0        1.000000
# 7                 0.0        0.000000
# 8                 0.0        0.000000
# 9                 0.0        0.000000
# 10                0.0        0.000000
# 11                0.0        0.000000
# 12                0.0        0.000000
# 13                0.0        0.000000
# 14                0.0        0.000000
# 15                0.0        0.000000
# 16                1.0        1.000000
# 17                1.0        0.500000
# 18                0.0        0.000000
# 19                0.0        0.000000
# 20                0.0        0.000000
# 21                0.0        0.000000
# 22                0.5        0.000000
# 23                1.0        0.000000
# 24                1.0        1.000000
# 25                1.0        1.000000
# 26                0.0        0.000000
# 27                0.0        0.000000
# 28                0.5        0.000000
# 29                1.0        1.000000
# 30                0.5        1.000000
# 31                0.0        0.000000
# 32                1.0        1.000000
# 33                0.0        0.000000
# 34                0.0        0.000000
# 35                1.0        1.000000
# 36                1.0        1.000000
# 37                1.0        1.000000
# 38                0.0        0.000000
# 39                0.0        0.000000
# 40                0.0        0.000000
# 41                1.0        1.000000
# 42                0.0        0.000000
# 43                0.0        0.000000
# 44                0.0        0.000000
# 45                0.0        0.000000
# 46                0.0        0.000000
# 47                0.0        0.000000
# 48                0.0        0.000000
# 49                0.0        0.000000

# %% [markdown]
# The following code initializes the **Featurizer** with the data loaded in the previous step

# %%
featurizer = Featurizer.from_pandas(df_test_dataset)

# %% [markdown]
# # 2. Create features automatically
#
# The following code uses an Azure OpenAI LLM deployment to create the features, by default the number of features is 12, but this number can be modified if required. If the quality of the black-box models is low, one option to improve it is to increase the number of features generated.
#
# The features automatically generated can be or **boolean** or **list of strings**. The goal is to be able to capture the characteristics of the different user queries in a way that can be easily interpretable by a human, and at the same time these features should be able to be engineered to be used as regressors for the black-box regression models.
#
# The following is an example of how to create the features, and how to visualize them.

# %%
# %%time

featurizer.create_features_using_azure_openai(
    deployment_name="gpt-4o", # Update with the name of your Azure OpenAI LLM deployment name
    num_features=25
)
print(featurizer.features.model_dump_json(indent=4))
# Out:
# {
#     "features": [
#         {
#             "feature": "there_is_any_company_identified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_companies_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "there_is_any_topic_or_initiative_identified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_topics_or_initiatives_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "there_is_any_specific_metric_or_value_identified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_metrics_or_values_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "there_is_any_specific_page_or_section_identified_in_the_question",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "list_of_pages_or_sections_identified_in_the_question",
#             "ftype": "list_of_strings"
#         },
#         {
#             "feature": "is_a_question_about_comparison_or_trends",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_specific_facts_or_data_points",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_goals_or_targets",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_actions_or_measures_taken",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_environmental_or_sustainability_topics",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_social_or_community_impact",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_policy_or_advocacy",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_financial_or_economic_aspects",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_technological_or_innovative_aspects",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_historical_or_past_data",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_future_projections_or_plans",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_document_structure_or_content",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_testimonials_or_quotes",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_partnerships_or_collaborations",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_emissions_or_climate_change",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_resource_management_or_efficiency",
#             "ftype": "boolean"
#         },
#         {
#             "feature": "is_a_question_about_diversity_or_inclusion",
#             "ftype": "boolean"
#         }
#     ]
# }
# CPU times: user 84.2 ms, sys: 6.15 ms, total: 90.4 ms
# Wall time: 7.56 s

# %% [markdown]
# These automatically generated features can be modified if required. For this, just use the `featurizer.features.features` list to remove or add features. For example, to remove the second question (index = 1), you can use `del` as follows:
#
# ```python
# del featurizer.features.features[1]
# ```
#
# To add an additional feature, you can use `append` as follows:
#
# ```python
# from genaishap import Feature
#
# featurizer.features.features.append(
#     Feature(
#         feature="is_an_open_ended_question",
#         ftype="boolean"
#     )
# )
# ```

# %% [markdown]
# # 3. Fill out the features automatically
#
# Once the list of features is created it is possible to automatically fill out the values of each feature using the **Featurizer**. The **Featurizer** uses an Azure OpenAI LLM to do the job. The batch size parameter is used to fill out batches of, for example, 5 questions. The batch size helps to control the number of tokens used per LLM call.

# %%
# %%time

featurizer.fill_out_features_using_azure_openai(
    deployment_name="gpt-4o", 
    batch_size=5
)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 346 ms, sys: 47.3 ms, total: 394 ms
# Wall time: 43 s

# %%
df_features = featurizer.to_pandas()
df_features.style.set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '5pt')]}]
).set_properties(**{'font-size': '8pt',})
# Out:
# <style type="text/css">
# #T_fc77e th {
#   font-size: 5pt;
# }
# #T_fc77e_row0_col0, #T_fc77e_row0_col1, #T_fc77e_row0_col2, #T_fc77e_row0_col3, #T_fc77e_row0_col4, #T_fc77e_row0_col5, #T_fc77e_row0_col6, #T_fc77e_row0_col7, #T_fc77e_row0_col8, #T_fc77e_row0_col9, #T_fc77e_row0_col10, #T_fc77e_row0_col11, #T_fc77e_row0_col12, #T_fc77e_row0_col13, #T_fc77e_row0_col14, #T_fc77e_row0_col15, #T_fc77e_row0_col16, #T_fc77e_row0_col17, #T_fc77e_row0_col18, #T_fc77e_row0_col19, #T_fc77e_row0_col20, #T_fc77e_row0_col21, #T_fc77e_row0_col22, #T_fc77e_row0_col23, #T_fc77e_row0_col24, #T_fc77e_row1_col0, #T_fc77e_row1_col1, #T_fc77e_row1_col2, #T_fc77e_row1_col3, #T_fc77e_row1_col4, #T_fc77e_row1_col5, #T_fc77e_row1_col6, #T_fc77e_row1_col7, #T_fc77e_row1_col8, #T_fc77e_row1_col9, #T_fc77e_row1_col10, #T_fc77e_row1_col11, #T_fc77e_row1_col12, #T_fc77e_row1_col13, #T_fc77e_row1_col14, #T_fc77e_row1_col15, #T_fc77e_row1_col16, #T_fc77e_row1_col17, #T_fc77e_row1_col18, #T_fc77e_row1_col19, #T_fc77e_row1_col20, #T_fc77e_row1_col21, #T_fc77e_row1_col22, #T_fc77e_row1_col23, #T_fc77e_row1_col24, #T_fc77e_row2_col0, #T_fc77e_row2_col1, #T_fc77e_row2_col2, #T_fc77e_row2_col3, #T_fc77e_row2_col4, #T_fc77e_row2_col5, #T_fc77e_row2_col6, #T_fc77e_row2_col7, #T_fc77e_row2_col8, #T_fc77e_row2_col9, #T_fc77e_row2_col10, #T_fc77e_row2_col11, #T_fc77e_row2_col12, #T_fc77e_row2_col13, #T_fc77e_row2_col14, #T_fc77e_row2_col15, #T_fc77e_row2_col16, #T_fc77e_row2_col17, #T_fc77e_row2_col18, #T_fc77e_row2_col19, #T_fc77e_row2_col20, #T_fc77e_row2_col21, #T_fc77e_row2_col22, #T_fc77e_row2_col23, #T_fc77e_row2_col24, #T_fc77e_row3_col0, #T_fc77e_row3_col1, #T_fc77e_row3_col2, #T_fc77e_row3_col3, #T_fc77e_row3_col4, #T_fc77e_row3_col5, #T_fc77e_row3_col6, #T_fc77e_row3_col7, #T_fc77e_row3_col8, #T_fc77e_row3_col9, #T_fc77e_row3_col10, #T_fc77e_row3_col11, #T_fc77e_row3_col12, #T_fc77e_row3_col13, #T_fc77e_row3_col14, #T_fc77e_row3_col15, #T_fc77e_row3_col16, #T_fc77e_row3_col17, #T_fc77e_row3_col18, #T_fc77e_row3_col19, #T_fc77e_row3_col20, #T_fc77e_row3_col21, #T_fc77e_row3_col22, #T_fc77e_row3_col23, #T_fc77e_row3_col24, #T_fc77e_row4_col0, #T_fc77e_row4_col1, #T_fc77e_row4_col2, #T_fc77e_row4_col3, #T_fc77e_row4_col4, #T_fc77e_row4_col5, #T_fc77e_row4_col6, #T_fc77e_row4_col7, #T_fc77e_row4_col8, #T_fc77e_row4_col9, #T_fc77e_row4_col10, #T_fc77e_row4_col11, #T_fc77e_row4_col12, #T_fc77e_row4_col13, #T_fc77e_row4_col14, #T_fc77e_row4_col15, #T_fc77e_row4_col16, #T_fc77e_row4_col17, #T_fc77e_row4_col18, #T_fc77e_row4_col19, #T_fc77e_row4_col20, #T_fc77e_row4_col21, #T_fc77e_row4_col22, #T_fc77e_row4_col23, #T_fc77e_row4_col24, #T_fc77e_row5_col0, #T_fc77e_row5_col1, #T_fc77e_row5_col2, #T_fc77e_row5_col3, #T_fc77e_row5_col4, #T_fc77e_row5_col5, #T_fc77e_row5_col6, #T_fc77e_row5_col7, #T_fc77e_row5_col8, #T_fc77e_row5_col9, #T_fc77e_row5_col10, #T_fc77e_row5_col11, #T_fc77e_row5_col12, #T_fc77e_row5_col13, #T_fc77e_row5_col14, #T_fc77e_row5_col15, #T_fc77e_row5_col16, #T_fc77e_row5_col17, #T_fc77e_row5_col18, #T_fc77e_row5_col19, #T_fc77e_row5_col20, #T_fc77e_row5_col21, #T_fc77e_row5_col22, #T_fc77e_row5_col23, #T_fc77e_row5_col24, #T_fc77e_row6_col0, #T_fc77e_row6_col1, #T_fc77e_row6_col2, #T_fc77e_row6_col3, #T_fc77e_row6_col4, #T_fc77e_row6_col5, #T_fc77e_row6_col6, #T_fc77e_row6_col7, #T_fc77e_row6_col8, #T_fc77e_row6_col9, #T_fc77e_row6_col10, #T_fc77e_row6_col11, #T_fc77e_row6_col12, #T_fc77e_row6_col13, #T_fc77e_row6_col14, #T_fc77e_row6_col15, #T_fc77e_row6_col16, #T_fc77e_row6_col17, #T_fc77e_row6_col18, #T_fc77e_row6_col19, #T_fc77e_row6_col20, #T_fc77e_row6_col21, #T_fc77e_row6_col22, #T_fc77e_row6_col23, #T_fc77e_row6_col24, #T_fc77e_row7_col0, #T_fc77e_row7_col1, #T_fc77e_row7_col2, #T_fc77e_row7_col3, #T_fc77e_row7_col4, #T_fc77e_row7_col5, #T_fc77e_row7_col6, #T_fc77e_row7_col7, #T_fc77e_row7_col8, #T_fc77e_row7_col9, #T_fc77e_row7_col10, #T_fc77e_row7_col11, #T_fc77e_row7_col12, #T_fc77e_row7_col13, #T_fc77e_row7_col14, #T_fc77e_row7_col15, #T_fc77e_row7_col16, #T_fc77e_row7_col17, #T_fc77e_row7_col18, #T_fc7 ...

# %% [markdown]
# It is possible to manually edit the values of the features or add or remove manually an entire column.  The easies way to do it is just to manipulate the `df_features` dataframe.  Unsing pandas Dataframe methods and functions it is easy to manipulate this table as required.  The following are the restrictions for the manual manipulation:
# - The total number of records of `df_features` has to be the same as the number of records of `df_test_dataset`.
# - The column names of `df_features` should be self explanatory since they are going to be used for the explanations.
# - The type of the columns in `df_features` needs to be **boolean** or **list of strings**.

# %% [markdown]
# # 4. Store features and values as JSON file

# %%
df_features.to_json('./test-features.json', orient='records', indent=4)

# %% [markdown]
# Just for visualization, the following cell shows in a single table all the columns calculated so far, user input, metrics and question features

# %%
df_test_dataset.join(df_features)
# Out:
#                                            user_input  \
# 0   What is the objective of the Carbon Call initi...
# 1   What are the three key areas that will enable ...
# 2   How many people in India did Microsoft provide...
# 3   How many people in Indonesia did Microsoft pro...
# 4   How many people in Brazil did Microsoft provid...
# 5   How many people in Mexico did Microsoft provid...
# 6   How many more acres of land does Microsoft nee...
# 7   What key insight was listed in page 56 of the ...
# 8   What key insight was listed in page 61 of the ...
# 9    What are the four commitments listed on page 66?
# 10  What is the last Key project listed under Poli...
# 11  What are the sub sections for "What We Create"...
# 12  What are the category labels for each topic in...
# 13  Can you provide for me the three highlights fo...
# 14  What percentage of waste from Google's offices...
# 15  Can you present me with the performance highli...
# 16  What was the listed key achievement regarding ...
# 17  Did Google reach its intended Waste target und...
# 18  How many EV charging locations were there on G...
# 19  On what page of the report can I find the perf...
# 20  Can you please provide for me the glossary of ...
# 21  On what page can I find details about Amazons ...
# 22  For the listed Renewable Energy goals, by when...
# 23  Can you provide the Actions taken by Amazon fo...
# 24  What were Amazon's Carbon Intesity values in (...
# 25  What were Amazon's Total Carbon Footprint (MMT...
# 26  On what page can of the report can I find info...
# 27  What household brands were featured in the in ...
# 28  What percentage of corporate emissions since 2...
# 29  In Apple's comprehensive carbon footprint, wha...
# 30  By what percentage did Apple reduce plastic in...
# 31  How many metric tons of waste were redirected ...
# 32  In 2021, how many hours were spent by staff ac...
# 33  How many millions of gallons of freshwater was...
# 34  What were the Total Packaging resources used i...
# 35  How many pages and groups were removed for rep...
# 36  How many artifacts were removed from Facebook ...
# 37  How many unique visitors to the Facebook Marke...
# 38  How many users were surveyed for their views o...
# 39  What were the subsections for the 2021 Highlig...
# 40  What are the subsections of the Workplaces sec...
# 41   What is the fact about Oceans shared on page 43?
# 42  What are the 4 facts shared in the Greenhouse ...
# 43  In the about netflix page, what are the mentio...
# 44  Who provided the testimonial on Netflix's Sust...
# 45  What are the Scope 1 and Scope 2 emission redu...
# 46  Who provided the testimonial on Netflix's Sust...
# 47         Can you provide the quote by Xiye Bastida?
# 48         Can you provide the quote by Aditi Sharma?
# 49  What 3 partner companies were spotlighted in t...
#
#                                    retrieved_contexts  \
# 0   [In 2022, we also released a preview version o...
# 1   [What’s next \nScope 3 emissions reduction \nM...
# 2   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 3   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 4   [Chile\nSouth Africa\n16,408 \nBrazil\n340  \n...
# 5   [Improving access \nto water \nWe continue to ...
# 6   [• • \na \n47\n | | | \nCommitments and progre...
# 7   [Leadership About Highlights How We Operate Wh...
# 8   [Leadership About Highlights How We Operate Wh...
# 9   [UN Sustainable Development Goal Apple’s suppo...
# 10  [Sometimes, that means joining \nregional coll...
# 11  [OUR APPROACH TO SUSTAINABILITY\nFor a Better ...
# 12  [Introduction Sustainability People Appendix \...
# 13  [31. In 2018, to align with industry best prac...
# 14  [Performance highlights\nThe following section...
# 15  [Education\nFor more than 40 years, we’ve work...
# 16  [Our approach\nWe believe that every business ...
# 17  [BUILDING BETTER DEVICES AND SERVICES\nTarget ...
# 18  [This guidance does not recognize existing ren...
# 19  [Employee Recruitment, Inclusion and Performan...
# 20  [GRI INDEX\nGRI 304 - Biodiversity\nGRI 103 Ma...
# 21  [IntroductionSustainability\nDriving Climate S...
# 22  [IntroductionSustainability\nDriving Climate S...
# 23  [IntroductionSustainability\nDriving Climate S...
# 24  [IntroductionSustainability\nDriving Climate S...
# 25  [IntroductionSustainability\nDriving Climate S...
# 26  [Tackling Climate  \nMisinformation\n \nClimat...
# 27  [Customer Shopping Experience\nWe have enabled...
# 28  [IntroductionSustainability\nDriving Climate S...
# 29  [Gross emissions\n   \nAvoided emissions\n  \n...
# 30  [Across our business, we released eight \nprod...
# 31  [Current\nyear\nBase\nyear\nTarget\nDiversion ...
# 32  [Growth and development\nWe want everyone to f...
# 33  [FY21 FY20 FY22\nCurrent yearBase year\n0M\n2M...
# 34  [IntroductionSustainability\nReducing Packagin...
# 35  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 36  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 37  [UNITED NATIONS SUSTAINABLE DEVELOPMENT GOALS\...
# 38  [TACKLING CLIMATE MISINFORMATION\n“Misinformat...
# 39  [2021 Highlights\nCelebrating today.\nWorking ...
# 40  [Employees have several feedback routes. While...
# 41  [PUSHPIN FACTS\nFACT SOURCE LINK\nEarly warnin...
# 42  [18Netflix ESG Report 2022\n2022 SCOPE 1 AND 2...
# 43  [3Netflix ESG Report 2022\nA letter from our c...
# 44  [24Netflix ESG Report 2022\nThe film and telev...
# 45  [What’s next \nScope 3 emissions reduction \nM...
# 46  [24Netflix ESG Report 2022\nThe film and telev...
# 47  [49Netflix ESG Report 2022\nAs a women-led B-C...
# 48  [Employee Recruitment, Inclusion and Performan...
# 49  [Introduct ion Sustainability People \nIncreas...
#
#                                              response  \
# 0   The objective of the Carbon Call initiative is...
# 1   The three key areas that will enable the scale...
# 2   Microsoft provided water access to 225,389 peo...
# 3   The specific number of people in Indonesia pro...
# 4   Microsoft provided water access to 552,058 peo...
# 5   Microsoft provided water access to 309,921 peo...
# 6   According to Ecosystems Chart 1, Microsoft has...
# 7   The context provided does not include informat...
# 8   The context provided does not include informat...
# 9   The four commitments listed on page 66 are: \n...
# 10  The last key project listed under the Policy a...
# 11  The sub-sections for the "What We Create" sect...
# 12  The context does not provide information about...
# 13  The three highlights for the GHG emissions sec...
# 14  The percentage of waste from Google's offices ...
# 15  Apple focuses on empowering users with technol...
# 16  There is no listed key achievement for Google ...
# 17  Yes, Google reached its intended Waste target ...
# 18  The provided information does not specify the ...
# 19  The performance highlights for the Empowering ...
# 20  The provided information does not include a gl...
# 21  Details about Amazon's climate solutions can b...
# 22  Amazon intends to have all operations powered ...
# 23  Amazon has taken several actions to achieve it...
# 24  Amazon's Carbon Intensity values (grams of CO2...
# 25  Amazon's Total Carbon Footprint (MMT CO2e) for...
# 26  The report does not mention "The Climate Page ...
# 27  The provided information does not include deta...
# 28  Since 2020, 100% of corporate electricity use ...
# 29  The top two categories leading to the most avo...
# 30  Apple reduced plastic in packaging by 75 perce...
# 31  The provided information does not specify the ...
# 32  In 2021, staff spent more than 175,000 hours p...
# 33  The provided information does not include data...
# 34  The provided information does not include data...
# 35  3,000 pages and groups were removed for repeat...
# 36  Over 12 million pieces of misleading COVID-19 ...
# 37  There were 368,000 unique visitors to the Face...
# 38  The provided information does not specify the ...
# 39  The subsections for the 2021 Highlights were: ...
# 40  The subsections of the Workplaces section of t...
# 41  The fact about oceans shared is that they abso...
# 42  The context does not provide specific facts fr...
# 43  The mentioned highlights about the company inc...
# 44  The provided context does not include a testim...
# 45  The provided information does not specifically...
# 46  The provided context does not include a testim...
# 47  The provided information does not include a qu...
# 48  The provided context does not include a quote ...
# 49  The Inclusion and Diversity section does not s...
#
#                                             reference  faithfulness  \
# 0   The objective of Carbon Call is to unify the w...      1.000000
# 1   1 Advancing AI solutions for greater climate i...      0.750000
# 2                                             309,921      0.000000
# 3                                             225,389      1.000000
# 4                                              16,408      1.000000
# 5                                                 340      0.000000
# 6                                     4998 more acres      0.800000
# 7   25%\nWe are reducing idle power consumption of...      1.000000
# 8   100%\nOur key European and American distributi...      1.000000
# 9   1. Using our voice on climate-related public p...      0.250000
# 10  Making green jobs, skills, and entrepreneurshi...      0.500000
# 11  Raising Awareness, Tackling Climate Misinforma...      0.888889
# 12                Important, Very Important, Critical      1.000000
# 13  Sure, they are: \n1. 65% cumulative GHG emissi...      0.857143
# 14                                Sixty-four percent.      1.000000
# 15  Sure! The Performance Highlights for Empowerin...      0.900000
# 16  In 2017, Google became the first major company...      1.000000
# 17  No, this target has not been met in 2021. Howe...      0.500000
# 18                                             200000      1.000000
# 19  The performance highlights for Empowering User...      1.000000
# 20  Sure, here is the glossary:\nGlossary\nCFE: ca...      1.000000
# 21  You can find information on driving climate so...      0.000000
# 22  Amazon set the goal of becoming powered by 100...      1.000000
# 23  Sure, here they are:\nActions\n90% Electricity...      1.000000
# 24  Sure, here they are:\n2019: 122.8\n2020: 102.7...      1.000000
# 25  Amazon's total footprint for the years 2019-20...      1.000000
# 26                                         On page 14      1.000000
# 27  Microsoft, jetBlue, Uber, Mercedez-Benz, Visa,...      1.000000
# 28                             100% since April 2020.      0.000000
# 29  The top two categories were: supplier clean en...      1.000000
# 30                                                75%      1.000000
# 31  More than 2 million metric tons of waste were ...      1.000000
# 32                                       175000 hours      1.000000
# 33  7600 million gallons of freshwater were saved ...      1.000000
# 34  2021: 257000\n2020: 226000\n2019: 189000\n2018...      1.000000
# 35                                               3000      0.000000
# 36                                           12000000      1.000000
# 37                                             368000      1.000000
# 38                   76328 users across 31 countries.      1.000000
# 39  1 Protecting People and Planet Through Respons...      1.000000
# 40  1. Healthy and Sustainable Workplaces\n2. Offi...      0.750000
# 41  Oceans absorb more than 90% ofthe heat that re...      0.500000
# 42  1. CO2 emissions are increasing more than 250 ...      1.000000
# 43  Public in 2002\nFounded in 1997\n231M paid mem...      1.000000
# 44  Christiana Figueres,\nDiplomat and Architect o...      1.000000
# 45  1 Energy Efficiency\n2 Renewable Energy (elect...      0.583333
# 46  Elizabeth Sturcken,\nManaging Director, Enviro...      1.000000
# 47  Young people like myself view Netflix as a che...      1.000000
# 48  Through the Take Ten program, I got to learn a...      1.000000
# 49  1. Black Economic Development Fund\n2. Hope Cr...      0.000000
#
#     context_precision  context_recall  \
# 0                 1.0        1.000000
# 1                 0.0        0.666667
# 2                 0.0        0.000000
# 3                 1.0        0.000000
# 4                 1.0        0.000000
# 5                 0.0        1.000000
# 6                 1.0        1.000000
# 7                 0.0        0.000000
# 8                 0.0        0.000000
# 9                 0.0        0.000000
# 10                0.0        0.000000
# 11                0.0        0.000000
# 12                0.0        0.000000
# 13                0.0        0.000000
# 14                0.0        0.000000
# 15                0.0        0.000000
# 16                1.0        1.000000
# 17                1.0        0.500000
# 18                0.0        0.000000
# 19                0.0        0.000000
# 20                0.0        0.000000
# 21                0.0        0.000000
# 22                0.5        0.000000
# 23                1.0        0.000000
# 24                1.0        1.000000
# 25                1.0        1.000000
# 26                0.0        0.000000
# 27                0.0        0.000000
# 28                0.5        0.000000
# 29                1.0        1.000000
# 30                0.5        1.000000
# 31                0.0        0.000000
# 32                1.0        1.000000
# 33                0.0        0.000000
# 34                0.0        0.000000
# 35                1.0        1.000000
# 36                1.0        1.000000
# 37                1.0        1.000000
# 38                0.0        0.000000
# 39                0.0        0.000000
# 40                0.0        0.000000
# 41                1.0        1.000000
# 42                0.0        0.000000
# 43                0.0        0.000000
# 44                0.0        0.000000
# 45                0.0        0.000000
# 46                0.0        0.000000
# 47                0.0        0.000000
# 48                0.0        0.000000
# 49                0.0        0.000000
#
#     there_is_any_company_identified_in_the_question  \
# 0                                             False
# 1                                             False
# 2                                              True
# 3                                              True
# 4                                              True
# 5                                              True
# 6                                              True
# 7                                             False
# 8                                             False
# 9                                             False
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                             True
# 15                                            False
# 16                                             True
# 17                                             True
# 18                                             True
# 19                                            False
# 20                                            False
# 21                                             True
# 22                                             True
# 23                                             True
# 24                                             True
# 25                                             True
# 26                                            False
# 27                                            False
# 28                                            False
# 29                                             True
# 30                                             True
# 31                                             True
# 32                                             True
# 33                                             True
# 34                                             True
# 35                                             True
# 36                                             True
# 37                                             True
# 38                                            False
# 39                                            False
# 40                                            False
# 41                                            False
# 42                                            False
# 43                                             True
# 44                                             True
# 45                                            False
# 46                                             True
# 47                                            False
# 48                                            False
# 49                                            False
#
#    list_of_companies_identified_in_the_question  \
# 0                                            []
# 1                                            []
# 2                                   [Microsoft]
# 3                                   [Microsoft]
# 4                                   [Microsoft]
# 5                                   [Microsoft]
# 6                                   [Microsoft]
# 7                                            []
# 8                                            []
# 9                                            []
# 10                                           []
# 11                                           []
# 12                                           []
# 13                                           []
# 14                                     [Google]
# 15                                           []
# 16                                     [Google]
# 17                                     [Google]
# 18                                     [Google]
# 19                                           []
# 20                                           []
# 21                                     [Amazon]
# 22                                     [Amazon]
# 23                                     [Amazon]
# 24                                     [Amazon]
# 25                                     [Amazon]
# 26                                           []
# 27                                           []
# 28                                           []
# 29                                      [Apple]
# 30                                      [Apple]
# 31                                      [Apple]
# 32                                      [Apple]
# 33                                      [Apple]
# 34                                      [Apple]
# 35                                       [Meta]
# 36                                   [Facebook]
# 37                                   [Facebook]
# 38                                           []
# 39                                           []
# 40                                           []
# 41                                           []
# 42                                           []
# 43                                    [Netflix]
# 44                                    [Netflix]
# 45                                           []
# 46                                    [Netflix]
# 47                                           []
# 48                                           []
# 49                                           []
#
#     there_is_any_topic_or_initiative_identified_in_the_question  ...  \
# 0                                                True            ...
# 1                                                True            ...
# 2                                                True            ...
# 3                                                True            ...
# 4                                                True            ...
# 5                                                True            ...
# 6                                                True            ...
# 7                                               False            ...
# 8                                               False            ...
# 9                                                True            ...
# 10                                               True            ...
# 11                                               True            ...
# 12                                               True            ...
# 13                                               True            ...
# 14                                               True            ...
# 15                                               True            ...
# 16                                               True            ...
# 17                                               True            ...
# 18                                               True            ...
# 19                                               True            ...
# 20                                              False            ...
# 21                                               True            ...
# 22                                               True            ...
# 23                                               True            ...
# 24                                               True            ...
# 25                                               True            ...
# 26                                               True            ...
# 27                                               True            ...
# 28                                               True            ...
# 29                                               True            ...
# 30                                               True            ...
# 31                                               True            ...
# 32                                               True            ...
# 33                                               True            ...
# 34                                               True            ...
# 35                                               True            ...
# 36                                               True            ...
# 37                                               True            ...
# 38                                               True            ...
# 39                                               True            ...
# 40                                               True            ...
# 41                                               True            ...
# 42                                               True            ...
# 43                                               True            ...
# 44                                               True            ...
# 45                                               True            ...
# 46                                               True            ...
# 47                                              False            ...
# 48                                              False            ...
# 49                                               True            ...
#
#    is_a_question_about_financial_or_economic_aspects  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
# 7                                              False
# 8                                              False
# 9                                              False
# 10                                             False
# 11                                             False
# 12                                             False
# 13                                             False
# 14                                             False
# 15                                             False
# 16                                             False
# 17                                             False
# 18                                             False
# 19                                             False
# 20                                             False
# 21                                             False
# 22                                             False
# 23                                             False
# 24                                              True
# 25                                             False
# 26                                             False
# 27                                             False
# 28                                             False
# 29                                             False
# 30                                             False
# 31                                             False
# 32                                             False
# 33                                             False
# 34                                             False
# 35                                             False
# 36                                             False
# 37                                              True
# 38                                             False
# 39                                             False
# 40                                             False
# 41                                             False
# 42                                             False
# 43                                              True
# 44                                             False
# 45                                             False
# 46                                             False
# 47                                             False
# 48                                             False
# 49                                             False
#
#     is_a_question_about_technological_or_innovative_aspects  \
# 0                                               False
# 1                                                True
# 2                                               False
# 3                                               False
# 4                                               False
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
# 15                                               True
# 16                                              False
# 17                                              False
# 18                                               True
# 19                                               True
# 20                                              False
# 21                                              False
# 22                                              False
# 23                                              False
# 24                                              False
# 25                                              False
# 26                                              False
# 27                                              False
# 28                                               True
# 29                                               True
# 30                                              False
# 31                                              False
# 32                                               True
# 33                                              False
# 34                                              False
# 35                                              False
# 36                                              False
# 37                                               True
# 38                                              False
# 39                                              False
# 40                                              False
# 41                                              False
# 42                                              False
# 43                                               True
# 44                                              False
# 45                                              False
# 46                                              False
# 47                                              False
# 48                                              False
# 49                                              False
#
#    is_a_question_about_historical_or_past_data  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
# 7                                        False
# 8                                        False
# 9                                        False
# 10                                       False
# 11                                       False
# 12                                       False
# 13                                       False
# 14                                        True
# 15                                       False
# 16                                        True
# 17                                        True
# 18                                        True
# 19                                       False
# 20                                       False
# 21                                       False
# 22                                       False
# 23                                       False
# 24                                        True
# 25                                        True
# 26                                       False
# 27                                       False
# 28                                        True
# 29                                       False
# 30                                        True
# 31                                       False
# 32                                        True
# 33                                        True
# 34                                        True
# 35                                        True
# 36                                        True
# 37                                        True
# 38                                        True
# 39                                        True
# 40                                       False
# 41                                       False
# 42                                       False
# 43                                       False
# 44                                       False
# 45                                       False
# 46                                       False
# 47                                       False
# 48                                       False
# 49                                       False
#
#     is_a_question_about_future_projections_or_plans  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                             False
# 5                                             False
# 6                                              True
# 7                                             False
# 8                                             False
# 9                                              True
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
# 15                                            False
# 16                                            False
# 17                                            False
# 18                                            False
# 19                                            False
# 20                                            False
# 21                                            False
# 22                                             True
# 23                                             True
# 24                                            False
# 25                                            False
# 26                                            False
# 27                                            False
# 28                                            False
# 29                                            False
# 30                                            False
# 31                                            False
# 32                                            False
# 33                                            False
# 34                                            False
# 35                                            False
# 36                                            False
# 37                                            False
# 38                                            False
# 39                                            False
# 40                                            False
# 41                                            False
# 42                                            False
# 43                                            False
# 44                                            False
# 45                                             True
# 46                                            False
# 47                                            False
# 48                                            False
# 49                                            False
#
#    is_a_question_about_document_structure_or_content  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
# 6                                              False
# 7                                               True
# 8                                               True
# 9                                               True
# 10                                              True
# 11                                              True
# 12                                              True
# 13                                              True
# 14                                             False
# 15                                             False
# 16                                             False
# 17                                             False
# 18                                             False
# 19                                              True
# 20                                              True
# 21                                              True
# 22                                             False
# 23                                             False
# 24                                             False
# 25                                             False
# 26                                              True
# 27                                              True
# 28                                             False
# 29                                             False
# 30                                             False
# 31                                             False
# 32                                             False
# 33                                             False
# 34                                             False
# 35                                             False
# 36                                             False
# 37                                             False
# 38                                             False
# 39                                              True
# 40                                              True
# 41                                              True
# 42                                              True
# 43                                              True
# 44                                             False
# 45                                             False
# 46                                             False
# 47                                             False
# 48                                             False
# 49                                              True
#
#     is_a_question_about_testimonials_or_quotes  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
# 7                                        False
# 8                                        False
# 9                                        False
# 10                                       False
# 11                                       False
# 12                                       False
# 13                                       False
# 14                                       False
# 15                                       False
# 16                                       False
# 17                                       False
# 18                                       False
# 19                                       False
# 20                                       False
# 21                                       False
# 22                                       False
# 23                                       False
# 24                                       False
# 25                                       False
# 26                                       False
# 27                                       False
# 28                                       False
# 29                                       False
# 30                                       False
# 31                                       False
# 32                                       False
# 33                                       False
# 34                                       False
# 35                                       False
# 36                                       False
# 37                                       False
# 38                                       False
# 39                                       False
# 40                                       False
# 41                                       False
# 42                                       False
# 43                                       False
# 44                                        True
# 45                                       False
# 46                                        True
# 47                                        True
# 48                                        True
# 49                                       False
#
#     is_a_question_about_partnerships_or_collaborations  \
# 0                                               False
# 1                                               False
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                               False
# 6                                               False
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
# 15                                              False
# 16                                              False
# 17                                              False
# 18                                              False
# 19                                              False
# 20                                              False
# 21                                              False
# 22                                              False
# 23                                               True
# 24                                              False
# 25                                              False
# 26                                              False
# 27                                               True
# 28                                              False
# 29                                              False
# 30                                              False
# 31                                               True
# 32                                              False
# 33                                               True
# 34                                              False
# 35                                              False
# 36                                              False
# 37                                              False
# 38                                              False
# 39                                              False
# 40                                              False
# 41                                              False
# 42                                              False
# 43                                              False
# 44                                               True
# 45                                              False
# 46                                              False
# 47                                              False
# 48                                              False
# 49                                               True
#
#     is_a_question_about_emissions_or_climate_change  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                             False
# 5                                             False
# 6                                             False
# 7                                             False
# 8                                             False
# 9                                             False
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                             True
# 14                                             True
# 15                                            False
# 16                                             True
# 17                                             True
# 18                                             True
# 19                                            False
# 20                                            False
# 21                                             True
# 22                                             True
# 23                                             True
# 24                                             True
# 25                                             True
# 26                                             True
# 27                                             True
# 28                                             True
# 29                                             True
# 30                                            False
# 31                                             True
# 32                                            False
# 33                                             True
# 34                                             True
# 35                                            False
# 36                                            False
# 37                                            False
# 38                                             True
# 39                                            False
# 40                                            False
# 41                                             True
# 42                                             True
# 43                                            False
# 44                                            False
# 45                                             True
# 46                                             True
# 47                                            False
# 48                                            False
# 49                                            False
#
#     is_a_question_about_resource_management_or_efficiency  \
# 0                                               False
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                                True
# 6                                                True
# 7                                               False
# 8                                               False
# 9                                               False
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                               True
# 15                                              False
# 16                                              False
# 17                                               True
# 18                                               True
# 19                                              False
# 20                                              False
# 21                                              False
# 22                                               True
# 23                                               True
# 24                                               True
# 25                                              False
# 26                                              False
# 27                                              False
# 28                                               True
# 29                                               True
# 30                                               True
# 31                                               True
# 32                                              False
# 33                                               True
# 34                                               True
# 35                                              False
# 36                                              False
# 37                                              False
# 38                                              False
# 39                                              False
# 40                                              False
# 41                                              False
# 42                                               True
# 43                                              False
# 44                                              False
# 45                                               True
# 46                                              False
# 47                                              False
# 48                                              False
# 49                                              False
#
#     is_a_question_about_diversity_or_inclusion
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
# 7                                        False
# 8                                        False
# 9                                        False
# 10                                       False
# 11                                       False
# 12                                       False
# 13                                       False
# 14                                       False
# 15                                       False
# 16                                       False
# 17                                       False
# 18                                       False
# 19                                       False
# 20                                       False
# 21                                       False
# 22                                       False
# 23                                       False
# 24                                       False
# 25                                       False
# 26                                       False
# 27                                       False
# 28                                       False
# 29                                       False
# 30                                       False
# 31                                       False
# 32                                        True
# 33                                       False
# 34                                       False
# 35                                       False
# 36                                       False
# 37                                       False
# 38                                       False
# 39                                       False
# 40                                        True
# 41                                       False
# 42                                       False
# 43                                       False
# 44                                       False
# 45                                       False
# 46                                       False
# 47                                       False
# 48                                       False
# 49                                        True
#
# [50 rows x 32 columns]
